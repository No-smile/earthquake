# %% [markdown]
# <a href="https://colab.research.google.com/github/No-smile/earthquake/blob/training_phasenet/examples/03a_training_phasenet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/seisbench/seisbench/blob/additional_example_workflows/examples/03a_training_phasenet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image](https://raw.githubusercontent.com/seisbench/seisbench/main/docs/_static/seisbench_logo_subtitle_outlined.svg)

# %% [markdown]
# *This code is necessary on colab to install SeisBench. If SeisBench is already installed on your machine, you can skip this.*

# %%
# !pip install seisbench
# Out:
# Requirement already satisfied: seisbench in /usr/local/lib/python3.11/dist-packages (0.9.1)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from seisbench) (2.0.2)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.11/dist-packages (from seisbench) (2.2.2)
# Requirement already satisfied: h5py>=3.1 in /usr/local/lib/python3.11/dist-packages (from seisbench) (3.14.0)
# Requirement already satisfied: obspy>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from seisbench) (1.4.2)
# Requirement already satisfied: tqdm>=4.52 in /usr/local/lib/python3.11/dist-packages (from seisbench) (4.67.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from seisbench) (2.6.0+cu124)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from seisbench) (1.15.3)
# Requirement already satisfied: nest_asyncio>=1.5.3 in /usr/local/lib/python3.11/dist-packages (from seisbench) (1.6.0)
# Requirement already satisfied: bottleneck>=1.3 in /usr/local/lib/python3.11/dist-packages (from seisbench) (1.4.2)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.11/dist-packages (from obspy>=1.3.1->seisbench) (3.10.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from obspy>=1.3.1->seisbench) (5.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from obspy>=1.3.1->seisbench) (75.2.0)
# Requirement already satisfied: sqlalchemy<2 in /usr/local/lib/python3.11/dist-packages (from obspy>=1.3.1->seisbench) (1.4.54)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from obspy>=1.3.1->seisbench) (4.4.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from obspy>=1.3.1->seisbench) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1->seisbench) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1->seisbench) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1->seisbench) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->seisbench) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.10.0->seisbench) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->obspy>=1.3.1->seisbench) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->obspy>=1.3.1->seisbench) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->obspy>=1.3.1->seisbench) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->obspy>=1.3.1->seisbench) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->obspy>=1.3.1->seisbench) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->obspy>=1.3.1->seisbench) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->obspy>=1.3.1->seisbench) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1->seisbench) (1.17.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<2->obspy>=1.3.1->seisbench) (3.2.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.10.0->seisbench) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->obspy>=1.3.1->seisbench) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->obspy>=1.3.1->seisbench) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->obspy>=1.3.1->seisbench) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->obspy>=1.3.1->seisbench) (2025.7.9)

# %% [markdown]
# *This cell is required to circumvent an issue with colab and obspy. For details, check this issue in the obspy documentation: https://github.com/obspy/obspy/issues/2547*

# %%
try:
    import obspy
    obspy.read()
except TypeError:
    # Needs to restart the runtime once, because obspy only works properly after restart.
    print('Stopping RUNTIME. If you run this code for the first time, this is expected. Colaboratory will restart automatically. Please run again.')
    exit()

# %% [markdown]
# # Training PhaseNet
#
# This tutorial shows how to train a model with SeisBench, using PhaseNet as an example. This brings together the three main components of SeisBench: data, models and generate.
#
# The tutorial is intended to highlight the basic principles of training models in SeisBench. However, this will not necessarily be best practice for more elaborate experiments. As a reference how to set up larger studies and which augmentations can be used for which models, we refer to the implementation of our pick benchmark at [https://github.com/seisbench/pick-benchmark](https://github.com/seisbench/pick-benchmark).
#
# *Note: As this tutorial brings together different parts of seisbench, it is recommended to go through the basic tutorials first before beginning this tutorial. In addition, this tutorial assumes some familiarity with pytorch*

# %%
import seisbench.data as sbd
import seisbench.generate as sbg
import seisbench.models as sbm
from seisbench.util import worker_seeding

import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
from obspy.clients.fdsn import Client
from obspy import UTCDateTime

# %% [markdown]
# ## Model and data
#
# We create a randomly initialized PhaseNet model using `seisbench.models`. If available, you can move your model onto GPU, running CUDA or MPS (on Apple silicon). In Google Colab, you can select a GPU under "Runtime > Change runtime type".

# %%
model = sbm.PhaseNet(phases="PSN", norm="std", default_args={"blinding": (200, 200)})

if torch.cuda.is_available():
    model.cuda()
    print("Running on GPU")
elif torch.backends.mps.is_available():
    model.to("mps")
    print("Running on MPS")
else:
    print("Running on CPU")
# Out:
# Running on CPU

# %% [markdown]
# As training data we use the ETHZ dataset. Note that we set the sampling rate to 100 Hz to ensure that all examples are consistent in terms of sampling rate. We split the data into training, development and test sets according to the splits provided.

# %%
data = sbd.Iquique(sampling_rate=50)
train, dev, test = data.train_dev_test()
# Out:
# 2025-07-12 16:34:18,123 | seisbench | WARNING | Check available storage and memory before downloading and general use of Iquique dataset. Dataset size: waveforms.hdf5 ~5Gb, metadata.csv ~2.6Mb
# WARNING:seisbench:Check available storage and memory before downloading and general use of Iquique dataset. Dataset size: waveforms.hdf5 ~5Gb, metadata.csv ~2.6Mb
# 2025-07-12 16:34:19,373 | seisbench | WARNING | Dataset Iquique not in cache.
# WARNING:seisbench:Dataset Iquique not in cache.
# 2025-07-12 16:34:19,375 | seisbench | WARNING | Trying to download preprocessed version from SeisBench repository.
# WARNING:seisbench:Trying to download preprocessed version from SeisBench repository.
#
# Downloading metadata:   0%|          | 0.00/2.57M [00:00<?, ?B/s]
# Downloading metadata:   1%|          | 16.0k/2.57M [00:00<00:36, 74.3kB/s]
# Downloading metadata:   2%|▏         | 48.0k/2.57M [00:00<00:22, 117kB/s]
# Downloading metadata:   4%|▎         | 97.0k/2.57M [00:00<00:15, 166kB/s]
# Downloading metadata:   8%|▊         | 208k/2.57M [00:00<00:08, 300kB/s]
# Downloading metadata:  16%|█▌        | 417k/2.57M [00:01<00:04, 535kB/s]
# Downloading metadata:  32%|███▏      | 833k/2.57M [00:01<00:01, 998kB/s]
# Downloading metadata: 100%|██████████| 2.57M/2.57M [00:01<00:00, 1.69MB/s]
#
# Downloading waveforms:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# Downloading waveforms:   0%|          | 16.0k/4.98G [00:00<20:22:11, 72.9kB/s]
# Downloading waveforms:   0%|          | 48.0k/4.98G [00:00<12:57:06, 115kB/s]
# Downloading waveforms:   0%|          | 129k/4.98G [00:00<6:29:56, 229kB/s]
# Downloading waveforms:   0%|          | 289k/4.98G [00:00<3:20:40, 444kB/s]
# Downloading waveforms:   0%|          | 609k/4.98G [00:01<1:49:35, 813kB/s]
# Downloading waveforms:   0%|          | 1.20M/4.98G [00:01<59:21, 1.50MB/s]
# Downloading waveforms:   0%|          | 2.42M/4.98G [00:01<31:09, 2.86MB/s]
# Downloading waveforms:   0%|          | 4.88M/4.98G [00:01<16:00, 5.56MB/s]
# Downloading waveforms:   0%|          | 8.58M/4.98G [00:02<10:13, 8.70MB/s]
# Downloading waveforms:   0%|          | 12.2M/4.98G [00:02<08:08, 10.9MB/s]
# Downloading waveforms:   0%|          | 14.9M/4.98G [00:02<07:51, 11.3MB/s]
# Downloading waveforms:   0%|          | 18.5M/4.98G [00:02<06:53, 12.9MB/s]
# Downloading waveforms:   0%|          | 22.1M/4.98G [00:03<06:34, 13.5MB/s]
# Downloading waveforms:   1%|          | 25.6M/4.98G [00:03<06:15, 14.2MB/s]
# Downloading waveforms:   1%|          | 28.8M/4.98G [00:03<06:08, 14.4MB/s]
# Downloading waveforms:   1%|          | 32.5M/4.98G [00:03<06:09, 14.4MB/s]
# Downloading waveforms:   1%|          | 36.0M/4.98G [00:03<06:01, 14.7MB/s]
# Downloading waveforms:   1%|          | 39.3M/4.98G [00:04<05:58, 14.8MB/s]
# Downloading waveforms:   1%|          | 42.9M/4.98G [00:04<05:55, 14.9MB/s]
# Downloading waveforms:   1%|          | 46.5M/4.98G [00:04<05:51, 15.1MB/s]
# Downloading waveforms:   1%|          | 49.6M/4.98G [00:04<05:56, 14.9MB/s]
# Downloading waveforms:   1%|          | 52.9M/4.98G [00:05<05:55, 14.9MB/s]
# Downloading waveforms:   1%|          | 56.5M/4.98G [00:05<05:43, 15.4MB/s]
# Downloading waveforms:   1%|          | 59.6M/4.98G [00:05<05:52, 15.0MB/s]
# Downloading waveforms:   1%|          | 63.3M/4.98G [00:05<05:59, 14.7MB/s]
# Downloading waveforms:   1%|▏         | 66.7M/4.98G [00:06<05:51, 15.0MB/s]
# Downloading waveforms:   1%|▏         | 69.9M/4.98G [00:06<05:52, 15.0MB/s]
# Downloading waveforms:   1%|▏         | 72.9M/4.98G [00:06<06:01, 14.6MB/s]
# Downloading waveforms:   1%|▏         | 76.5M/4.98G [00:06<05:48, 15.1MB/s]
# Downloading waveforms:   2%|▏         | 79.4M/4.98G [00:06<05:01, 17.5MB/s]
# Downloading waveforms:   2%|▏         | 81.2M/4.98G [00:07<05:53, 14.9MB/s]
# Downloading waveforms:   2%|▏         | 82.8M/4.98G [00:07<06:15, 14.0MB/s]
# Downloading waveforms:   2%|▏         | 84.9M/4.98G [00:07<05:38, 15.5MB/s]
# Downloading waveforms:   2%|▏         | 86.6M/4.98G [00:07<06:39, 13.2MB/s]
# Downloading waveforms:   2%|▏         | 89.1M/4.98G [00:07<06:11, 14.1MB/s]
# Downloading waveforms:   2%|▏         | 90.7M/4.98G [00:07<05:56, 14.7MB/s]
# Downloading waveforms:   2%|▏         | 92.2M/4.98G [00:07<06:13, 14.1MB/s]
# Downloading waveforms:   2%|▏         | 93.6M/4.98G [00:08<06:11, 14.1MB/s]
# Downloading waveforms:   2%|▏         | 95.6M/4.98G [00:08<05:54, 14.8MB/s]
# Downloading waveforms:   2%|▏         | 97.0M/4.98G [00:08<06:12, 14.1MB/s]
# Downloading waveforms:   2%|▏         | 98.6M/4.98G [00:08<05:59, 14.6MB/s]
# Downloading waveforms:   2%|▏         | 100M/4.98G [00:08<06:14, 14.0MB/s]
# Downloading waveforms:   2%|▏         | 102M/4.98G [00:08<05:58, 14.6MB/s]
# Downloading waveforms:   2%|▏         | 103M/4.98G [00:08<06:17, 13.9MB/s]
# Downloading waveforms:   2%|▏         | 105M/4.98G [00:08<05:54, 14.8MB/s]
# Downloading waveforms:   2%|▏         | 106M/4.98G [00:09<06:31, 13.4MB/s]
# Downloading waveforms:   2%|▏         | 108M/4.98G [00:09<05:43, 15.2MB/s]
# Downloading waveforms:   2%|▏         | 110M/4.98G [00:09<06:38, 13.1MB/s]
# Downloading waveforms:   2%|▏         | 112M/4.98G [00:09<06:51, 12.7MB/s]
# Downloading waveforms:   2%|▏         | 114M/4.98G [00:09<05:49, 15.0MB/s]
# Downloading waveforms:   2%|▏         | 116M/4.98G [00:09<06:22, 13.7MB/s]
# Downloading waveforms:   2%|▏         | 118M/4.98G [00:09<07:00, 12.4MB/s]
# Downloading waveforms:   2%|▏         | 121M/4.98G [00:10<06:28, 13.4MB/s]
# Downloading waveforms:   2%|▏         | 124M/4.98G [00:10<06:18, 13.8MB/s]
# Downloading waveforms:   2%|▏         | 127M/4.98G [00:10<06:22, 13.6MB/s]
# Downloading waveforms:   3%|▎         | 130M/4.98G [00:10<06:26, 13.5MB/s]
# Downloading waveforms:   3%|▎         | 134M/4.98G [00:11<06:05, 14.2MB/s]
# Downloading waveforms:   3%|▎         | 138M/4.98G [00:11<05:53, 14.7MB/s]
# Downloading waveforms:   3%|▎         | 140M/4.98G [00:11<06:18, 13.7MB/s]
# Downloading waveforms:   3%|▎         | 143M/4.98G [00:11<05:09, 16.8MB/s]
# Downloading waveforms:   3%|▎         | 145M/4.98G [00:11<05:45, 15.0MB/s]
# Downloading waveforms:   3%|▎         | 147M/4.98G [00:12<06:33, 13.2MB/s]
# Downloading waveforms:   3%|▎         | 150M/4.98G [00:12<06:24, 13.5MB/s]
# Downloading waveforms:   3%|▎         | 153M/4.98G [00:12<06:25, 13.5MB/s]
# Downloading waveforms:   3%|▎         | 156M/4.98G [00:12<05:22, 16.0MB/s]
# Downloading waveforms:   3%|▎         | 157M/4.98G [00:12<06:03, 14.3MB/s]
# Downloading waveforms:   3%|▎         | 159M/4.98G [00:12<06:28, 13.3MB/s]
# Downloading waveforms:   3%|▎         | 162M/4.98G [00:13<06:14, 13.8MB/s]
# Downloading waveforms:   3%|▎         | 165M/4.98G [00:13<05:11, 16.6MB/s]
# Downloading waveforms:   3%|▎         | 167M/4.98G [00:13<06:09, 14.0MB/s]
# Downloading waveforms:   3%|▎         | 169M/4.98G [00:13<06:10, 14.0MB/s]
# Downloading waveforms:   3%|▎         | 171M/4.98G [00:13<05:24, 15.9MB/s]
# Downloading waveforms:   3%|▎         | 173M/4.98G [00:13<06:31, 13.2MB/s]
# Downloading waveforms:   3%|▎         | 176M/4.98G [00:14<06:44, 12.8MB/s]
# Downloading waveforms:   3%|▎         | 178M/4.98G [00:14<06:45, 12.7MB/s]
# Downloading waveforms:   4%|▎         | 181M/4.98G [00:14<06:40, 12.9MB/s]
# Downloading waveforms:   4%|▎         | 184M/4.98G [00:14<06:37, 13.0MB/s]
# Downloading waveforms:   4%|▎         | 188M/4.98G [00:15<06:12, 13.8MB/s]
# Downloading waveforms:   4%|▎         | 190M/4.98G [00:15<06:25, 13.3MB/s]
# Downloading waveforms:   4%|▍         | 193M/4.98G [00:15<06:26, 13.3MB/s]
# Downloading waveforms:   4%|▍         | 196M/4.98G [00:15<06:22, 13.5MB/s]
# Downloading waveforms:   4%|▍         | 199M/4.98G [00:16<06:20, 13.5MB/s]
# Downloading waveforms:   4%|▍         | 203M/4.98G [00:16<06:04, 14.1MB/s]
# Downloading waveforms:   4%|▍         | 206M/4.98G [00:16<05:49, 14.7MB/s]
# Downloading waveforms:   4%|▍         | 209M/4.98G [00:16<04:56, 17.3MB/s]
# Downloading waveforms:   4%|▍         | 211M/4.98G [00:16<05:43, 14.9MB/s]
# Downloading waveforms:   4%|▍         | 213M/4.98G [00:16<06:14, 13.7MB/s]
# Downloading waveforms:   4%|▍         | 215M/4.98G [00:17<05:07, 16.7MB/s]
# Downloading waveforms:   4%|▍         | 217M/4.98G [00:17<06:15, 13.6MB/s]
# Downloading waveforms:   4%|▍         | 219M/4.98G [00:17<06:10, 13.8MB/s]
# Downloading waveforms:   4%|▍         | 221M/4.98G [00:17<05:52, 14.5MB/s]
# Downloading waveforms:   4%|▍         | 222M/4.98G [00:17<06:17, 13.5MB/s]
# Downloading waveforms:   4%|▍         | 224M/4.98G [00:17<05:22, 15.8MB/s]
# Downloading waveforms:   4%|▍         | 226M/4.98G [00:17<06:44, 12.6MB/s]
# Downloading waveforms:   4%|▍         | 229M/4.98G [00:18<05:48, 14.6MB/s]
# Downloading waveforms:   5%|▍         | 230M/4.98G [00:18<05:54, 14.4MB/s]
# Downloading waveforms:   5%|▍         | 232M/4.98G [00:18<06:27, 13.2MB/s]
# Downloading waveforms:   5%|▍         | 235M/4.98G [00:18<05:45, 14.8MB/s]
# Downloading waveforms:   5%|▍         | 236M/4.98G [00:18<05:51, 14.5MB/s]
# Downloading waveforms:   5%|▍         | 238M/4.98G [00:18<05:35, 15.2MB/s]
# Downloading waveforms:   5%|▍         | 240M/4.98G [00:18<05:43, 14.8MB/s]
# Downloading waveforms:   5%|▍         | 241M/4.98G [00:19<05:44, 14.8MB/s]
# Downloading waveforms:   5%|▍         | 243M/4.98G [00:19<05:29, 15.4MB/s]
# Downloading waveforms:   5%|▍         | 245M/4.98G [00:19<05:30, 15.4MB/s]
# Downloading waveforms:   5%|▍         | 247M/4.98G [00:19<05:12, 16.3MB/s]
# Downloading waveforms:   5%|▍         | 249M/4.98G [00:19<05:19, 15.9MB/s]
# Downloading waveforms:   5%|▍         | 250M/4.98G [00:19<05:16, 16.1MB/s]
# Downloading waveforms:   5%|▍         | 252M/4.98G [00:19<05:29, 15.4MB/s]
# Downloading waveforms:   5%|▍         | 254M/4.98G [00:19<05:31, 15.3MB/s]
# Downloading waveforms:   5%|▌         | 256M/4.98G [00:19<05:29, 15.4MB/s]
# Downloading waveforms:   5%|▌         | 258M/4.98G [00:20<05:27, 15.5MB/s]
# Downloading waveforms:   5%|▌         | 259M/4.98G [00:20<05:34, 15.2MB/s]
# Downloading waveforms:   5%|▌         | 261M/4.98G [00:20<05:20, 15.8MB/s]
# Downloading waveforms:   5%|▌         | 263M/4.98G [00:20<05:27, 15.5MB/s]
# Downloading waveforms:   5%|▌         | 265M/4.98G [00:20<05:25, 15.6MB/s]
# Downloading waveforms:   5%|▌         | 266M/4.98G [00:20<05:39, 14.9MB/s]
# Downloading waveforms:   5%|▌         | 268M/4.98G [00:20<05:19, 15.9MB/s]
# Downloading waveforms:   5%|▌         | 270M/4.98G [00:20<05:34, 15.1MB/s]
# Downloading waveforms:   5%|▌         | 272M/4.98G [00:21<05:13, 16.1MB/s]
# Downloading waveforms:   5%|▌         | 273M/4.98G [00:21<05:31, 15.3MB/s]
# Downloading waveforms:   5%|▌         | 275M/4.98G [00:21<05:17, 15.9MB/s]
# Downloading waveforms:   5%|▌         | 277M/4.98G [00:21<05:33, 15.2MB/s]
# Downloading waveforms:   5%|▌         | 279M/4.98G [00:21<05:28, 15.4MB/s]
# Downloading waveforms:   6%|▌         | 281M/4.98G [00:21<05:27, 15.4MB/s]
# Downloading waveforms:   6%|▌         | 282M/4.98G [00:21<05:29, 15.3MB/s]
# Downloading waveforms:   6%|▌         | 284M/4.98G [00:21<05:37, 14.9MB/s]
# Downloading waveforms:   6%|▌         | 286M/4.98G [00:21<05:11, 16.2MB/s]
# Downloading waveforms:   6%|▌         | 288M/4.98G [00:22<05:24, 15.6MB/s]
# Downloading waveforms:   6%|▌         | 290M/4.98G [00:22<05:26, 15.5MB/s]
# Downloading waveforms:   6%|▌         | 291M/4.98G [00:22<05:44, 14.6MB/s]
# Downloading waveforms:   6%|▌         | 293M/4.98G [00:22<05:08, 16.4MB/s]
# Downloading waveforms:   6%|▌         | 295M/4.98G [00:22<05:37, 14.9MB/s]
# Downloading waveforms:   6%|▌         | 297M/4.98G [00:22<05:14, 16.0MB/s]
# Downloading waveforms:   6%|▌         | 298M/4.98G [00:22<05:32, 15.2MB/s]
# Downloading waveforms:   6%|▌         | 300M/4.98G [00:22<05:15, 16.0MB/s]
# Downloading waveforms:   6%|▌         | 302M/4.98G [00:23<05:32, 15.1MB/s]
# Downloading waveforms:   6%|▌         | 304M/4.98G [00:23<05:29, 15.2MB/s]
# Downloading waveforms:   6%|▌         | 306M/4.98G [00:23<05:14, 16.0MB/s]
# Downloading waveforms:   6%|▌         | 307M/4.98G [00:23<05:28, 15.3MB/s]
# Downloading waveforms:   6%|▌         | 309M/4.98G [00:23<05:25, 15.4MB/s]
# Downloading waveforms:   6%|▌         | 311M/4.98G [00:23<05:24, 15.5MB/s]
# Downloading waveforms:   6%|▌         | 313M/4.98G [00:23<05:22, 15.6MB/s]
# Downloading waveforms:   6%|▌         | 314M/4.98G [00:23<05:22, 15.6MB/s]
# Downloading waveforms:   6%|▌         | 316M/4.98G [00:24<05:11, 16.1MB/s]
# Downloading waveforms:   6%|▌         | 318M/4.98G [00:24<05:23, 15.5MB/s]
# Downloading waveforms:   6%|▋         | 320M/4.98G [00:24<05:06, 16.3MB/s]
# Downloading waveforms:   6%|▋         | 322M/4.98G [00:24<05:26, 15.4MB/s]
# Downloading waveforms:   6%|▋         | 324M/4.98G [00:24<05:00, 16.6MB/s]
# Downloading waveforms:   6%|▋         | 325M/4.98G [00:24<05:31, 15.1MB/s]
# Downloading waveforms:   6%|▋         | 327M/4.98G [00:24<05:32, 15.1MB/s]
# Downloading waveforms:   6%|▋         | 329M/4.98G [00:24<05:23, 15.4MB/s]
# Downloading waveforms:   6%|▋         | 331M/4.98G [00:25<05:26, 15.3MB/s]
# Downloading waveforms:   7%|▋         | 332M/4.98G [00:25<05:15, 15.9MB/s]
# Downloading waveforms:   7%|▋         | 334M/4.98G [00:25<05:25, 15.3MB/s]
# Downloading waveforms:   7%|▋         | 336M/4.98G [00:25<05:17, 15.7MB/s]
# Downloading waveforms:   7%|▋         | 338M/4.98G [00:25<05:28, 15.2MB/s]
# Downloading waveforms:   7%|▋         | 340M/4.98G [00:25<05:12, 16.0MB/s]
# Downloading waveforms:   7%|▋         | 341M/4.98G [00:25<05:26, 15.3MB/s]
# Downloading waveforms:   7%|▋         | 343M/4.98G [00:25<05:12, 16.0MB/s]
# Downloading waveforms:   7%|▋         | 345M/4.98G [00:25<05:31, 15.1MB/s]
# Downloading waveforms:   7%|▋         | 347M/4.98G [00:26<05:14, 15.9MB/s]
# Downloading waveforms:   7%|▋         | 348M/4.98G [00:26<05:25, 15.3MB/s]
# Downloading waveforms:   7%|▋         | 350M/4.98G [00:26<05:14, 15.8MB/s]
# Downloading waveforms:   7%|▋         | 352M/4.98G [00:26<05:22, 15.4MB/s]
# Downloading waveforms:   7%|▋         | 354M/4.98G [00:26<05:17, 15.7MB/s]
# Downloading waveforms:   7%|▋         | 355M/4.98G [00:26<05:26, 15.2MB/s]
# Downloading waveforms:   7%|▋         | 357M/4.98G [00:26<05:14, 15.8MB/s]
# Downloading waveforms:   7%|▋         | 359M/4.98G [00:26<05:16, 15.7MB/s]
# Downloading waveforms:   7%|▋         | 361M/4.98G [00:27<05:14, 15.8MB/s]
# Downloading waveforms:   7%|▋         | 363M/4.98G [00:27<05:21, 15.4MB/s]
# Downloading waveforms:   7%|▋         | 364M/4.98G [00:27<05:19, 15.5MB/s]
# Downloading waveforms:   7%|▋         | 366M/4.98G [00:27<05:17, 15.6MB/s]
# Downloading waveforms:   7%|▋         | 368M/4.98G [00:27<05:11, 15.9MB/s]
# Downloading waveforms:   7%|▋         | 370M/4.98G [00:27<05:18, 15.6MB/s]
# Downloading waveforms:   7%|▋         | 372M/4.98G [00:27<05:17, 15.6MB/s]
# Downloading waveforms:   7%|▋         | 373M/4.98G [00:27<05:20, 15.4MB/s]
# Downloading waveforms:   7%|▋         | 375M/4.98G [00:28<05:13, 15.8MB/s]
# Downloading waveforms:   7%|▋         | 377M/4.98G [00:28<05:13, 15.8MB/s]
# Downloading waveforms:   7%|▋         | 379M/4.98G [00:28<05:10, 15.9MB/s]
# Downloading waveforms:   7%|▋         | 380M/4.98G [00:28<05:15, 15.7MB/s]
# Downloading waveforms:   8%|▊         | 382M/4.98G [00:28<05:18, 15.5MB/s]
# Downloading waveforms:   8%|▊         | 384M/4.98G [00:28<05:26, 15.1MB/s]
# Downloading waveforms:   8%|▊         | 386M/4.98G [00:28<05:12, 15.8MB/s]
# Downloading waveforms:   8%|▊         | 388M/4.98G [00:28<05:17, 15.6MB/s]
# Downloading waveforms:   8%|▊         | 389M/4.98G [00:28<05:25, 15.2MB/s]
# Downloading waveforms:   8%|▊         | 391M/4.98G [00:29<05:17, 15.6MB/s]
# Downloading waveforms:   8%|▊         | 393M/4.98G [00:29<05:22, 15.3MB/s]
# Downloading waveforms:   8%|▊         | 395M/4.98G [00:29<05:03, 16.3MB/s]
# Downloading waveforms:   8%|▊         | 397M/4.98G [00:29<05:20, 15.4MB/s]
# Downloading waveforms:   8%|▊         | 398M/4.98G [00:29<05:05, 16.1MB/s]
# Downloading waveforms:   8%|▊         | 400M/4.98G [00:29<05:16, 15.6MB/s]
# Downloading waveforms:   8%|▊         | 402M/4.98G [00:29<05:20, 15.4MB/s]
# Downloading waveforms:   8%|▊         | 404M/4.98G [00:29<05:11, 15.8MB/s]
# Downloading waveforms:   8%|▊         | 405M/4.98G [00:30<05:24, 15.1MB/s]
# Downloading waveforms:   8%|▊         | 407M/4.98G [00:30<05:17, 15.5MB/s]
# Downloading waveforms:   8%|▊         | 409M/4.98G [00:30<05:08, 15.9MB/s]
# Downloading waveforms:   8%|▊         | 411M/4.98G [00:30<05:18, 15.4MB/s]
# Downloading waveforms:   8%|▊         | 413M/4.98G [00:30<05:12, 15.7MB/s]
# Downloading waveforms:   8%|▊         | 414M/4.98G [00:30<05:25, 15.1MB/s]
# Downloading waveforms:   8%|▊         | 416M/4.98G [00:30<04:55, 16.6MB/s]
# Downloading waveforms:   8%|▊         | 418M/4.98G [00:30<05:21, 15.3MB/s]
# Downloading waveforms:   8%|▊         | 420M/4.98G [00:30<04:54, 16.7MB/s]
# Downloading waveforms:   8%|▊         | 422M/4.98G [00:31<05:24, 15.1MB/s]
# Downloading waveforms:   8%|▊         | 423M/4.98G [00:31<05:13, 15.7MB/s]
# Downloading waveforms:   8%|▊         | 425M/4.98G [00:31<05:19, 15.4MB/s]
# Downloading waveforms:   8%|▊         | 427M/4.98G [00:31<05:16, 15.5MB/s]
# Downloading waveforms:   8%|▊         | 429M/4.98G [00:31<05:18, 15.4MB/s]
# Downloading waveforms:   8%|▊         | 430M/4.98G [00:31<05:20, 15.3MB/s]
# Downloading waveforms:   8%|▊         | 432M/4.98G [00:31<05:12, 15.6MB/s]
# Downloading waveforms:   9%|▊         | 434M/4.98G [00:31<05:13, 15.6MB/s]
# Downloading waveforms:   9%|▊         | 436M/4.98G [00:32<05:23, 15.1MB/s]
# Downloading waveforms:   9%|▊         | 438M/4.98G [00:32<05:06, 16.0MB/s]
# Downloading waveforms:   9%|▊         | 439M/4.98G [00:32<05:20, 15.2MB/s]
# Downloading waveforms:   9%|▊         | 441M/4.98G [00:32<05:16, 15.4MB/s]
# Downloading waveforms:   9%|▊         | 443M/4.98G [00:32<05:14, 15.5MB/s]
# Downloading waveforms:   9%|▊         | 445M/4.98G [00:32<05:13, 15.6MB/s]
# Downloading waveforms:   9%|▉         | 447M/4.98G [00:32<05:10, 15.7MB/s]
# Downloading waveforms:   9%|▉         | 448M/4.98G [00:32<05:10, 15.7MB/s]
# Downloading waveforms:   9%|▉         | 450M/4.98G [00:33<05:11, 15.6MB/s]
# Downloading waveforms:   9%|▉         | 452M/4.98G [00:33<05:12, 15.6MB/s]
# Downloading waveforms:   9%|▉         | 454M/4.98G [00:33<05:06, 15.9MB/s]
# Downloading waveforms:   9%|▉         | 455M/4.98G [00:33<05:09, 15.7MB/s]
# Downloading waveforms:   9%|▉         | 457M/4.98G [00:33<05:05, 16.0MB/s]
# Downloading waveforms:   9%|▉         | 459M/4.98G [00:33<05:08, 15.8MB/s]
# Downloading waveforms:   9%|▉         | 461M/4.98G [00:33<05:22, 15.1MB/s]
# Downloading waveforms:   9%|▉         | 463M/4.98G [00:33<05:05, 15.9MB/s]
# Downloading waveforms:   9%|▉         | 464M/4.98G [00:34<05:21, 15.1MB/s]
# Downloading waveforms:   9%|▉         | 466M/4.98G [00:34<05:00, 16.1MB/s]
# Downloading waveforms:   9%|▉         | 468M/4.98G [00:34<05:19, 15.2MB/s]
# Downloading waveforms:   9%|▉         | 470M/4.98G [00:34<05:10, 15.6MB/s]
# Downloading waveforms:   9%|▉         | 472M/4.98G [00:34<05:06, 15.8MB/s]
# Downloading waveforms:   9%|▉         | 473M/4.98G [00:34<05:10, 15.6MB/s]
# Downloading waveforms:   9%|▉         | 475M/4.98G [00:34<04:58, 16.2MB/s]
# Downloading waveforms:   9%|▉         | 477M/4.98G [00:34<05:10, 15.6MB/s]
# Downloading waveforms:   9%|▉         | 479M/4.98G [00:34<05:07, 15.7MB/s]
# Downloading waveforms:   9%|▉         | 481M/4.98G [00:35<05:05, 15.9MB/s]
# Downloading waveforms:   9%|▉         | 482M/4.98G [00:35<05:30, 14.7MB/s]
# Downloading waveforms:   9%|▉         | 484M/4.98G [00:35<05:00, 16.1MB/s]
# Downloading waveforms:  10%|▉         | 486M/4.98G [00:35<05:25, 14.8MB/s]
# Downloading waveforms:  10%|▉         | 488M/4.98G [00:35<04:53, 16.5MB/s]
# Downloading waveforms:  10%|▉         | 490M/4.98G [00:35<05:19, 15.1MB/s]
# Downloading waveforms:  10%|▉         | 491M/4.98G [00:35<04:58, 16.2MB/s]
# Downloading waveforms:  10%|▉         | 493M/4.98G [00:35<05:10, 15.6MB/s]
# Downloading waveforms:  10%|▉         | 495M/4.98G [00:36<05:02, 16.0MB/s]
# Downloading waveforms:  10%|▉         | 497M/4.98G [00:36<05:17, 15.2MB/s]
# Downloading waveforms:  10%|▉         | 498M/4.98G [00:36<05:10, 15.5MB/s]
# Downloading waveforms:  10%|▉         | 500M/4.98G [00:36<05:15, 15.3MB/s]
# Downloading waveforms:  10%|▉         | 502M/4.98G [00:36<05:03, 15.9MB/s]
# Downloading waveforms:  10%|▉         | 504M/4.98G [00:36<05:17, 15.2MB/s]
# Downloading waveforms:  10%|▉         | 506M/4.98G [00:36<05:06, 15.7MB/s]
# Downloading waveforms:  10%|▉         | 507M/4.98G [00:36<05:13, 15.4MB/s]
# Downloading waveforms:  10%|▉         | 509M/4.98G [00:37<05:00, 16.0MB/s]
# Downloading waveforms:  10%|█         | 511M/4.98G [00:37<05:13, 15.4MB/s]
# Downloading waveforms:  10%|█         | 513M/4.98G [00:37<05:00, 16.0MB/s]
# Downloading waveforms:  10%|█         | 515M/4.98G [00:37<05:17, 15.2MB/s]
# Downloading waveforms:  10%|█         | 516M/4.98G [00:37<05:07, 15.6MB/s]
# Downloading waveforms:  10%|█         | 518M/4.98G [00:37<05:12, 15.4MB/s]
# Downloading waveforms:  10%|█         | 520M/4.98G [00:37<05:03, 15.8MB/s]
# Downloading waveforms:  10%|█         | 521M/4.98G [00:37<05:19, 15.0MB/s]
# Downloading waveforms:  10%|█         | 523M/4.98G [00:37<04:57, 16.1MB/s]
# Downloading waveforms:  10%|█         | 525M/4.98G [00:38<05:09, 15.5MB/s]
# Downloading waveforms:  10%|█         | 527M/4.98G [00:38<04:50, 16.5MB/s]
# Downloading waveforms:  10%|█         | 529M/4.98G [00:38<05:25, 14.7MB/s]
# Downloading waveforms:  10%|█         | 531M/4.98G [00:38<04:54, 16.2MB/s]
# Downloading waveforms:  10%|█         | 532M/4.98G [00:38<05:21, 14.9MB/s]
# Downloading waveforms:  10%|█         | 534M/4.98G [00:38<04:51, 16.4MB/s]
# Downloading waveforms:  11%|█         | 536M/4.98G [00:38<05:17, 15.1MB/s]
# Downloading waveforms:  11%|█         | 538M/4.98G [00:38<05:05, 15.6MB/s]
# Downloading waveforms:  11%|█         | 539M/4.98G [00:39<05:03, 15.8MB/s]
# Downloading waveforms:  11%|█         | 541M/4.98G [00:39<05:13, 15.2MB/s]
# Downloading waveforms:  11%|█         | 543M/4.98G [00:39<04:52, 16.3MB/s]
# Downloading waveforms:  11%|█         | 545M/4.98G [00:39<05:10, 15.4MB/s]
# Downloading waveforms:  11%|█         | 546M/4.98G [00:39<04:57, 16.1MB/s]
# Downloading waveforms:  11%|█         | 548M/4.98G [00:39<05:06, 15.6MB/s]
# Downloading waveforms:  11%|█         | 550M/4.98G [00:39<05:19, 14.9MB/s]
# Downloading waveforms:  11%|█         | 552M/4.98G [00:39<05:00, 15.9MB/s]
# Downloading waveforms:  11%|█         | 554M/4.98G [00:40<05:16, 15.1MB/s]
# Downloading waveforms:  11%|█         | 555M/4.98G [00:40<04:58, 16.0MB/s]
# Downloading waveforms:  11%|█         | 557M/4.98G [00:40<05:09, 15.4MB/s]
# Downloading waveforms:  11%|█         | 559M/4.98G [00:40<05:03, 15.7MB/s]
# Downloading waveforms:  11%|█         | 561M/4.98G [00:40<05:13, 15.2MB/s]
# Downloading waveforms:  11%|█         | 563M/4.98G [00:40<05:01, 15.8MB/s]
# Downloading waveforms:  11%|█         | 564M/4.98G [00:40<05:14, 15.1MB/s]
# Downloading waveforms:  11%|█         | 566M/4.98G [00:40<04:52, 16.3MB/s]
# Downloading waveforms:  11%|█         | 568M/4.98G [00:40<05:01, 15.8MB/s]
# Downloading waveforms:  11%|█         | 570M/4.98G [00:41<05:06, 15.5MB/s]
# Downloading waveforms:  11%|█         | 571M/4.98G [00:41<05:35, 14.1MB/s]
# Downloading waveforms:  11%|█         | 574M/4.98G [00:41<04:51, 16.3MB/s]
# Downloading waveforms:  11%|█▏        | 575M/4.98G [00:41<05:22, 14.7MB/s]
# Downloading waveforms:  11%|█▏        | 577M/4.98G [00:41<04:41, 16.8MB/s]
# Downloading waveforms:  11%|█▏        | 579M/4.98G [00:41<05:18, 14.9MB/s]
# Downloading waveforms:  11%|█▏        | 581M/4.98G [00:41<04:47, 16.5MB/s]
# Downloading waveforms:  11%|█▏        | 583M/4.98G [00:41<05:10, 15.3MB/s]
# Downloading waveforms:  11%|█▏        | 585M/4.98G [00:42<04:36, 17.1MB/s]
# Downloading waveforms:  12%|█▏        | 587M/4.98G [00:42<05:02, 15.6MB/s]
# Downloading waveforms:  12%|█▏        | 588M/4.98G [00:42<07:12, 10.9MB/s]
# Downloading waveforms:  12%|█▏        | 592M/4.98G [00:42<06:03, 13.0MB/s]
# Downloading waveforms:  12%|█▏        | 594M/4.98G [00:42<04:52, 16.2MB/s]
# Downloading waveforms:  12%|█▏        | 596M/4.98G [00:43<05:37, 14.0MB/s]
# Downloading waveforms:  12%|█▏        | 599M/4.98G [00:43<06:01, 13.0MB/s]
# Downloading waveforms:  12%|█▏        | 602M/4.98G [00:43<05:34, 14.1MB/s]
# Downloading waveforms:  12%|█▏        | 606M/4.98G [00:43<05:20, 14.7MB/s]
# Downloading waveforms:  12%|█▏        | 610M/4.98G [00:43<05:10, 15.1MB/s]
# Downloading waveforms:  12%|█▏        | 613M/4.98G [00:44<05:06, 15.3MB/s]
# Downloading waveforms:  12%|█▏        | 617M/4.98G [00:44<05:04, 15.5MB/s]
# Downloading waveforms:  12%|█▏        | 620M/4.98G [00:44<04:56, 15.8MB/s]
# Downloading waveforms:  12%|█▏        | 623M/4.98G [00:44<04:42, 16.6MB/s]
# Downloading waveforms:  12%|█▏        | 625M/4.98G [00:44<04:56, 15.8MB/s]
# Downloading waveforms:  12%|█▏        | 626M/4.98G [00:45<05:03, 15.5MB/s]
# Downloading waveforms:  12%|█▏        | 628M/4.98G [00:45<05:09, 15.2MB/s]
# Downloading waveforms:  12%|█▏        | 629M/4.98G [00:45<05:04, 15.4MB/s]
# Downloading waveforms:  12%|█▏        | 631M/4.98G [00:45<04:58, 15.7MB/s]
# Downloading waveforms:  12%|█▏        | 633M/4.98G [00:45<05:04, 15.4MB/s]
# Downloading waveforms:  12%|█▏        | 635M/4.98G [00:45<05:01, 15.5MB/s]
# Downloading waveforms:  12%|█▏        | 636M/4.98G [00:45<05:16, 14.8MB/s]
# Downloading waveforms:  13%|█▎        | 638M/4.98G [00:45<04:45, 16.4MB/s]
# Downloading waveforms:  13%|█▎        | 640M/4.98G [00:45<05:13, 14.9MB/s]
# Downloading waveforms:  13%|█▎        | 642M/4.98G [00:46<04:44, 16.4MB/s]
# Downloading waveforms:  13%|█▎        | 644M/4.98G [00:46<05:13, 14.9MB/s]
# Downloading waveforms:  13%|█▎        | 645M/4.98G [00:46<05:03, 15.4MB/s]
# Downloading waveforms:  13%|█▎        | 647M/4.98G [00:46<05:06, 15.3MB/s]
# Downloading waveforms:  13%|█▎        | 649M/4.98G [00:46<05:04, 15.3MB/s]
# Downloading waveforms:  13%|█▎        | 651M/4.98G [00:46<04:56, 15.7MB/s]
# Downloading waveforms:  13%|█▎        | 652M/4.98G [00:46<05:01, 15.4MB/s]
# Downloading waveforms:  13%|█▎        | 654M/4.98G [00:46<05:00, 15.5MB/s]
# Downloading waveforms:  13%|█▎        | 656M/4.98G [00:47<04:55, 15.7MB/s]
# Downloading waveforms:  13%|█▎        | 658M/4.98G [00:47<04:54, 15.8MB/s]
# Downloading waveforms:  13%|█▎        | 660M/4.98G [00:47<04:58, 15.6MB/s]
# Downloading waveforms:  13%|█▎        | 661M/4.98G [00:47<05:13, 14.9MB/s]
# Downloading waveforms:  13%|█▎        | 663M/4.98G [00:47<04:50, 16.0MB/s]
# Downloading waveforms:  13%|█▎        | 665M/4.98G [00:47<05:10, 15.0MB/s]
# Downloading waveforms:  13%|█▎        | 666M/4.98G [00:47<05:12, 14.9MB/s]
# Downloading waveforms:  13%|█▎        | 669M/4.98G [00:47<04:47, 16.1MB/s]
# Downloading waveforms:  13%|█▎        | 670M/4.98G [00:48<05:04, 15.3MB/s]
# Downloading waveforms:  13%|█▎        | 672M/4.98G [00:48<04:54, 15.8MB/s]
# Downloading waveforms:  13%|█▎        | 674M/4.98G [00:48<05:01, 15.4MB/s]
# Downloading waveforms:  13%|█▎        | 675M/4.98G [00:48<04:51, 15.9MB/s]
# Downloading waveforms:  13%|█▎        | 677M/4.98G [00:48<04:57, 15.6MB/s]
# Downloading waveforms:  13%|█▎        | 679M/4.98G [00:48<05:14, 14.8MB/s]
# Downloading waveforms:  13%|█▎        | 681M/4.98G [00:48<04:48, 16.0MB/s]
# Downloading waveforms:  13%|█▎        | 683M/4.98G [00:48<05:10, 14.9MB/s]
# Downloading waveforms:  13%|█▎        | 684M/4.98G [00:48<04:51, 15.9MB/s]
# Downloading waveforms:  13%|█▎        | 686M/4.98G [00:49<05:05, 15.2MB/s]
# Downloading waveforms:  13%|█▎        | 688M/4.98G [00:49<04:52, 15.8MB/s]
# Downloading waveforms:  14%|█▎        | 690M/4.98G [00:49<05:00, 15.4MB/s]
# Downloading waveforms:  14%|█▎        | 692M/4.98G [00:49<04:46, 16.1MB/s]
# Downloading waveforms:  14%|█▎        | 693M/4.98G [00:49<05:00, 15.4MB/s]
# Downloading waveforms:  14%|█▎        | 695M/4.98G [00:49<04:45, 16.2MB/s]
# Downloading waveforms:  14%|█▎        | 697M/4.98G [00:49<05:08, 15.0MB/s]
# Downloading waveforms:  14%|█▎        | 699M/4.98G [00:49<04:41, 16.4MB/s]
# Downloading waveforms:  14%|█▎        | 701M/4.98G [00:50<04:59, 15.4MB/s]
# Downloading waveforms:  14%|█▍        | 702M/4.98G [00:50<04:46, 16.1MB/s]
# Downloading waveforms:  14%|█▍        | 704M/4.98G [00:50<05:10, 14.9MB/s]
# Downloading waveforms:  14%|█▍        | 706M/4.98G [00:50<04:51, 15.8MB/s]
# Downloading waveforms:  14%|█▍        | 708M/4.98G [00:50<04:59, 15.4MB/s]
# Downloading waveforms:  14%|█▍        | 709M/4.98G [00:50<04:47, 16.0MB/s]
# Downloading waveforms:  14%|█▍        | 711M/4.98G [00:50<04:53, 15.7MB/s]
# Downloading waveforms:  14%|█▍        | 713M/4.98G [00:50<04:52, 15.7MB/s]
# Downloading waveforms:  14%|█▍        | 715M/4.98G [00:51<05:06, 15.0MB/s]
# Downloading waveforms:  14%|█▍        | 717M/4.98G [00:51<04:48, 15.9MB/s]
# Downloading waveforms:  14%|█▍        | 718M/4.98G [00:51<05:03, 15.2MB/s]
# Downloading waveforms:  14%|█▍        | 720M/4.98G [00:51<04:48, 15.9MB/s]
# Downloading waveforms:  14%|█▍        | 722M/4.98G [00:51<04:50, 15.8MB/s]
# Downloading waveforms:  14%|█▍        | 724M/4.98G [00:51<04:52, 15.7MB/s]
# Downloading waveforms:  14%|█▍        | 725M/4.98G [00:51<05:07, 14.9MB/s]
# Downloading waveforms:  14%|█▍        | 727M/4.98G [00:51<04:46, 16.0MB/s]
# Downloading waveforms:  14%|█▍        | 729M/4.98G [00:51<05:07, 14.9MB/s]
# Downloading waveforms:  14%|█▍        | 731M/4.98G [00:52<04:47, 15.9MB/s]
# Downloading waveforms:  14%|█▍        | 732M/4.98G [00:52<04:51, 15.7MB/s]
# Downloading waveforms:  14%|█▍        | 734M/4.98G [00:52<04:53, 15.6MB/s]
# Downloading waveforms:  14%|█▍        | 736M/4.98G [00:52<05:03, 15.1MB/s]
# Downloading waveforms:  14%|█▍        | 738M/4.98G [00:52<04:46, 16.0MB/s]
# Downloading waveforms:  15%|█▍        | 739M/4.98G [00:52<05:08, 14.8MB/s]
# Downloading waveforms:  15%|█▍        | 742M/4.98G [00:52<04:33, 16.7MB/s]
# Downloading waveforms:  15%|█▍        | 743M/4.98G [00:52<05:07, 14.8MB/s]
# Downloading waveforms:  15%|█▍        | 745M/4.98G [00:53<04:36, 16.5MB/s]
# Downloading waveforms:  15%|█▍        | 747M/4.98G [00:53<05:04, 15.0MB/s]
# Downloading waveforms:  15%|█▍        | 749M/4.98G [00:53<04:35, 16.5MB/s]
# Downloading waveforms:  15%|█▍        | 751M/4.98G [00:53<05:03, 15.0MB/s]
# Downloading waveforms:  15%|█▍        | 752M/4.98G [00:53<04:38, 16.4MB/s]
# Downloading waveforms:  15%|█▍        | 754M/4.98G [00:53<05:03, 15.0MB/s]
# Downloading waveforms:  15%|█▍        | 756M/4.98G [00:53<04:42, 16.1MB/s]
# Downloading waveforms:  15%|█▍        | 758M/4.98G [00:53<04:47, 15.9MB/s]
# Downloading waveforms:  15%|█▍        | 759M/4.98G [00:54<04:58, 15.2MB/s]
# Downloading waveforms:  15%|█▍        | 761M/4.98G [00:54<04:46, 15.9MB/s]
# Downloading waveforms:  15%|█▍        | 763M/4.98G [00:54<04:52, 15.5MB/s]
# Downloading waveforms:  15%|█▍        | 765M/4.98G [00:54<05:06, 14.8MB/s]
# Downloading waveforms:  15%|█▌        | 767M/4.98G [00:54<04:43, 16.0MB/s]
# Downloading waveforms:  15%|█▌        | 768M/4.98G [00:54<05:05, 14.9MB/s]
# Downloading waveforms:  15%|█▌        | 770M/4.98G [00:54<04:34, 16.5MB/s]
# Downloading waveforms:  15%|█▌        | 772M/4.98G [00:54<05:00, 15.1MB/s]
# Downloading waveforms:  15%|█▌        | 774M/4.98G [00:54<04:34, 16.5MB/s]
# Downloading waveforms:  15%|█▌        | 775M/4.98G [00:55<05:00, 15.1MB/s]
# Downloading waveforms:  15%|█▌        | 777M/4.98G [00:55<04:37, 16.3MB/s]
# Downloading waveforms:  15%|█▌        | 779M/4.98G [00:55<05:00, 15.1MB/s]
# Downloading waveforms:  15%|█▌        | 781M/4.98G [00:55<04:34, 16.5MB/s]
# Downloading waveforms:  15%|█▌        | 783M/4.98G [00:55<05:01, 15.0MB/s]
# Downloading waveforms:  15%|█▌        | 785M/4.98G [00:55<04:31, 16.6MB/s]
# Downloading waveforms:  15%|█▌        | 786M/4.98G [00:55<04:58, 15.2MB/s]
# Downloading waveforms:  15%|█▌        | 788M/4.98G [00:55<04:37, 16.3MB/s]
# Downloading waveforms:  15%|█▌        | 790M/4.98G [00:56<04:44, 15.9MB/s]
# Downloading waveforms:  16%|█▌        | 791M/4.98G [00:56<04:55, 15.3MB/s]
# Downloading waveforms:  16%|█▌        | 793M/4.98G [00:56<04:43, 15.9MB/s]
# Downloading waveforms:  16%|█▌        | 795M/4.98G [00:56<04:50, 15.5MB/s]
# Downloading waveforms:  16%|█▌        | 797M/4.98G [00:56<05:03, 14.8MB/s]
# Downloading waveforms:  16%|█▌        | 799M/4.98G [00:56<04:40, 16.1MB/s]
# Downloading waveforms:  16%|█▌        | 801M/4.98G [00:56<05:03, 14.9MB/s]
# Downloading waveforms:  16%|█▌        | 803M/4.98G [00:56<04:33, 16.5MB/s]
# Downloading waveforms:  16%|█▌        | 804M/4.98G [00:57<05:01, 14.9MB/s]
# Downloading waveforms:  16%|█▌        | 806M/4.98G [00:57<04:34, 16.4MB/s]
# Downloading waveforms:  16%|█▌        | 808M/4.98G [00:57<04:59, 15.0MB/s]
# Downloading waveforms:  16%|█▌        | 810M/4.98G [00:57<04:40, 16.0MB/s]
# Downloading waveforms:  16%|█▌        | 811M/4.98G [00:57<04:52, 15.4MB/s]
# Downloading waveforms:  16%|█▌        | 813M/4.98G [00:57<04:44, 15.8MB/s]
# Downloading waveforms:  16%|█▌        | 815M/4.98G [00:57<04:46, 15.7MB/s]
# Downloading waveforms:  16%|█▌        | 817M/4.98G [00:57<04:43, 15.8MB/s]
# Downloading waveforms:  16%|█▌        | 818M/4.98G [00:57<04:44, 15.8MB/s]
# Downloading waveforms:  16%|█▌        | 820M/4.98G [00:58<04:35, 16.3MB/s]
# Downloading waveforms:  16%|█▌        | 822M/4.98G [00:58<04:39, 16.0MB/s]
# Downloading waveforms:  16%|█▌        | 824M/4.98G [00:58<04:31, 16.5MB/s]
# Downloading waveforms:  16%|█▌        | 825M/4.98G [00:58<05:13, 14.3MB/s]
# Downloading waveforms:  16%|█▌        | 828M/4.98G [00:58<04:39, 16.0MB/s]
# Downloading waveforms:  16%|█▋        | 829M/4.98G [00:58<05:05, 14.7MB/s]
# Downloading waveforms:  16%|█▋        | 831M/4.98G [00:58<04:32, 16.4MB/s]
# Downloading waveforms:  16%|█▋        | 833M/4.98G [00:58<04:59, 14.9MB/s]
# Downloading waveforms:  16%|█▋        | 835M/4.98G [00:59<04:45, 15.7MB/s]
# Downloading waveforms:  16%|█▋        | 836M/4.98G [00:59<04:53, 15.2MB/s]
# Downloading waveforms:  16%|█▋        | 838M/4.98G [00:59<04:47, 15.5MB/s]
# Downloading waveforms:  16%|█▋        | 840M/4.98G [00:59<04:48, 15.5MB/s]
# Downloading waveforms:  17%|█▋        | 842M/4.98G [00:59<04:42, 15.8MB/s]
# Downloading waveforms:  17%|█▋        | 843M/4.98G [00:59<05:00, 14.9MB/s]
# Downloading waveforms:  17%|█▋        | 845M/4.98G [00:59<04:35, 16.2MB/s]
# Downloading waveforms:  17%|█▋        | 847M/4.98G [00:59<04:56, 15.0MB/s]
# Downloading waveforms:  17%|█▋        | 849M/4.98G [01:00<04:41, 15.8MB/s]
# Downloading waveforms:  17%|█▋        | 851M/4.98G [01:00<04:49, 15.4MB/s]
# Downloading waveforms:  17%|█▋        | 852M/4.98G [01:00<04:40, 15.9MB/s]
# Downloading waveforms:  17%|█▋        | 854M/4.98G [01:00<04:56, 15.0MB/s]
# Downloading waveforms:  17%|█▋        | 856M/4.98G [01:00<04:36, 16.1MB/s]
# Downloading waveforms:  17%|█▋        | 857M/4.98G [01:00<05:05, 14.6MB/s]
# Downloading waveforms:  17%|█▋        | 860M/4.98G [01:00<04:29, 16.5MB/s]
# Downloading waveforms:  17%|█▋        | 861M/4.98G [01:00<04:56, 15.0MB/s]
# Downloading waveforms:  17%|█▋        | 863M/4.98G [01:00<04:26, 16.7MB/s]
# Downloading waveforms:  17%|█▋        | 865M/4.98G [01:01<04:53, 15.2MB/s]
# Downloading waveforms:  17%|█▋        | 867M/4.98G [01:01<04:36, 16.1MB/s]
# Downloading waveforms:  17%|█▋        | 868M/4.98G [01:01<04:41, 15.8MB/s]
# Downloading waveforms:  17%|█▋        | 870M/4.98G [01:01<04:50, 15.3MB/s]
# Downloading waveforms:  17%|█▋        | 872M/4.98G [01:01<04:40, 15.8MB/s]
# Downloading waveforms:  17%|█▋        | 874M/4.98G [01:01<04:46, 15.5MB/s]
# Downloading waveforms:  17%|█▋        | 875M/4.98G [01:01<04:33, 16.2MB/s]
# Downloading waveforms:  17%|█▋        | 877M/4.98G [01:01<04:50, 15.2MB/s]
# Downloading waveforms:  17%|█▋        | 879M/4.98G [01:02<05:12, 14.2MB/s]
# Downloading waveforms:  17%|█▋        | 881M/4.98G [01:02<04:42, 15.7MB/s]
# Downloading waveforms:  17%|█▋        | 882M/4.98G [01:02<05:08, 14.3MB/s]
# Downloading waveforms:  17%|█▋        | 884M/4.98G [01:02<04:39, 15.8MB/s]
# Downloading waveforms:  17%|█▋        | 886M/4.98G [01:02<05:05, 14.5MB/s]
# Downloading waveforms:  17%|█▋        | 888M/4.98G [01:02<04:35, 16.0MB/s]
# Downloading waveforms:  17%|█▋        | 890M/4.98G [01:02<04:58, 14.8MB/s]
# Downloading waveforms:  17%|█▋        | 891M/4.98G [01:02<04:36, 16.0MB/s]
# Downloading waveforms:  18%|█▊        | 893M/4.98G [01:03<04:53, 15.0MB/s]
# Downloading waveforms:  18%|█▊        | 895M/4.98G [01:03<04:32, 16.2MB/s]
# Downloading waveforms:  18%|█▊        | 897M/4.98G [01:03<04:46, 15.4MB/s]
# Downloading waveforms:  18%|█▊        | 899M/4.98G [01:03<04:36, 15.9MB/s]
# Downloading waveforms:  18%|█▊        | 900M/4.98G [01:03<04:37, 15.9MB/s]
# Downloading waveforms:  18%|█▊        | 902M/4.98G [01:03<04:36, 15.9MB/s]
# Downloading waveforms:  18%|█▊        | 904M/4.98G [01:03<04:39, 15.7MB/s]
# Downloading waveforms:  18%|█▊        | 906M/4.98G [01:03<04:35, 16.0MB/s]
# Downloading waveforms:  18%|█▊        | 907M/4.98G [01:04<05:03, 14.5MB/s]
# Downloading waveforms:  18%|█▊        | 910M/4.98G [01:04<04:27, 16.4MB/s]
# Downloading waveforms:  18%|█▊        | 911M/4.98G [01:04<04:54, 14.9MB/s]
# Downloading waveforms:  18%|█▊        | 913M/4.98G [01:04<04:23, 16.7MB/s]
# Downloading waveforms:  18%|█▊        | 915M/4.98G [01:04<04:49, 15.1MB/s]
# Downloading waveforms:  18%|█▊        | 917M/4.98G [01:04<04:31, 16.1MB/s]
# Downloading waveforms:  18%|█▊        | 918M/4.98G [01:04<04:57, 14.8MB/s]
# Downloading waveforms:  18%|█▊        | 920M/4.98G [01:04<04:38, 15.7MB/s]
# Downloading waveforms:  18%|█▊        | 922M/4.98G [01:04<04:45, 15.3MB/s]
# Downloading waveforms:  18%|█▊        | 924M/4.98G [01:05<04:40, 15.6MB/s]
# Downloading waveforms:  18%|█▊        | 926M/4.98G [01:05<04:35, 15.9MB/s]
# Downloading waveforms:  18%|█▊        | 927M/4.98G [01:05<04:45, 15.3MB/s]
# Downloading waveforms:  18%|█▊        | 929M/4.98G [01:05<04:37, 15.8MB/s]
# Downloading waveforms:  18%|█▊        | 931M/4.98G [01:05<05:09, 14.1MB/s]
# Downloading waveforms:  18%|█▊        | 933M/4.98G [01:05<04:56, 14.8MB/s]
# Downloading waveforms:  18%|█▊        | 934M/4.98G [01:05<04:57, 14.7MB/s]
# Downloading waveforms:  18%|█▊        | 936M/4.98G [01:05<04:47, 15.2MB/s]
# Downloading waveforms:  18%|█▊        | 938M/4.98G [01:06<04:42, 15.4MB/s]
# Downloading waveforms:  18%|█▊        | 940M/4.98G [01:06<04:45, 15.3MB/s]
# Downloading waveforms:  18%|█▊        | 942M/4.98G [01:06<04:50, 15.0MB/s]
# Downloading waveforms:  18%|█▊        | 943M/4.98G [01:06<04:42, 15.4MB/s]
# Downloading waveforms:  19%|█▊        | 945M/4.98G [01:06<04:40, 15.5MB/s]
# Downloading waveforms:  19%|█▊        | 947M/4.98G [01:06<04:42, 15.4MB/s]
# Downloading waveforms:  19%|█▊        | 949M/4.98G [01:06<04:50, 15.0MB/s]
# Downloading waveforms:  19%|█▊        | 950M/4.98G [01:06<04:38, 15.6MB/s]
# Downloading waveforms:  19%|█▊        | 952M/4.98G [01:07<04:39, 15.6MB/s]
# Downloading waveforms:  19%|█▊        | 954M/4.98G [01:07<04:44, 15.3MB/s]
# Downloading waveforms:  19%|█▊        | 956M/4.98G [01:07<04:40, 15.5MB/s]
# Downloading waveforms:  19%|█▉        | 957M/4.98G [01:07<04:42, 15.4MB/s]
# Downloading waveforms:  19%|█▉        | 959M/4.98G [01:07<04:48, 15.1MB/s]
# Downloading waveforms:  19%|█▉        | 961M/4.98G [01:07<04:36, 15.7MB/s]
# Downloading waveforms:  19%|█▉        | 963M/4.98G [01:07<04:48, 15.0MB/s]
# Downloading waveforms:  19%|█▉        | 964M/4.98G [01:07<04:39, 15.5MB/s]
# Downloading waveforms:  19%|█▉        | 966M/4.98G [01:07<04:36, 15.7MB/s]
# Downloading waveforms:  19%|█▉        | 968M/4.98G [01:08<04:41, 15.4MB/s]
# Downloading waveforms:  19%|█▉        | 970M/4.98G [01:08<04:46, 15.1MB/s]
# Downloading waveforms:  19%|█▉        | 972M/4.98G [01:08<04:35, 15.7MB/s]
# Downloading waveforms:  19%|█▉        | 973M/4.98G [01:08<04:46, 15.1MB/s]
# Downloading waveforms:  19%|█▉        | 975M/4.98G [01:08<04:26, 16.2MB/s]
# Downloading waveforms:  19%|█▉        | 977M/4.98G [01:08<04:52, 14.8MB/s]
# Downloading waveforms:  19%|█▉        | 979M/4.98G [01:08<04:30, 16.0MB/s]
# Downloading waveforms:  19%|█▉        | 980M/4.98G [01:08<04:49, 14.9MB/s]
# Downloading waveforms:  19%|█▉        | 982M/4.98G [01:09<04:31, 15.9MB/s]
# Downloading waveforms:  19%|█▉        | 984M/4.98G [01:09<04:44, 15.2MB/s]
# Downloading waveforms:  19%|█▉        | 986M/4.98G [01:09<04:36, 15.6MB/s]
# Downloading waveforms:  19%|█▉        | 987M/4.98G [01:09<04:45, 15.1MB/s]
# Downloading waveforms:  19%|█▉        | 989M/4.98G [01:09<04:32, 15.8MB/s]
# Downloading waveforms:  19%|█▉        | 991M/4.98G [01:09<04:47, 15.0MB/s]
# Downloading waveforms:  19%|█▉        | 993M/4.98G [01:09<04:19, 16.6MB/s]
# Downloading waveforms:  20%|█▉        | 994M/4.98G [01:09<04:52, 14.7MB/s]
# Downloading waveforms:  20%|█▉        | 996M/4.98G [01:10<04:27, 16.1MB/s]
# Downloading waveforms:  20%|█▉        | 998M/4.98G [01:10<04:51, 14.8MB/s]
# Downloading waveforms:  20%|█▉        | 0.98G/4.98G [01:10<04:23, 16.3MB/s]
# Downloading waveforms:  20%|█▉        | 0.98G/4.98G [01:10<04:49, 14.9MB/s]
# Downloading waveforms:  20%|█▉        | 0.98G/4.98G [01:10<04:32, 15.8MB/s]
# Downloading waveforms:  20%|█▉        | 0.98G/4.98G [01:10<04:37, 15.5MB/s]
# Downloading waveforms:  20%|█▉        | 0.98G/4.98G [01:10<04:45, 15.0MB/s]
# Downloading waveforms:  20%|█▉        | 0.99G/4.98G [01:10<04:28, 16.0MB/s]
# Downloading waveforms:  20%|█▉        | 0.99G/4.98G [01:11<04:45, 15.0MB/s]
# Downloading waveforms:  20%|█▉        | 0.99G/4.98G [01:11<04:46, 15.0MB/s]
# Downloading waveforms:  20%|█▉        | 0.99G/4.98G [01:11<04:34, 15.6MB/s]
# Downloading waveforms:  20%|█▉        | 0.99G/4.98G [01:11<04:30, 15.8MB/s]
# Downloading waveforms:  20%|█▉        | 0.99G/4.98G [01:11<04:31, 15.8MB/s]
# Downloading waveforms:  20%|█▉        | 1.00G/4.98G [01:11<04:28, 15.9MB/s]
# Downloading waveforms:  20%|██        | 1.00G/4.98G [01:11<04:29, 15.9MB/s]
# Downloading waveforms:  20%|██        | 1.00G/4.98G [01:11<04:30, 15.8MB/s]
# Downloading waveforms:  20%|██        | 1.00G/4.98G [01:11<04:18, 16.5MB/s]
# Downloading waveforms:  20%|██        | 1.00G/4.98G [01:12<04:25, 16.1MB/s]
# Downloading waveforms:  20%|██        | 1.00G/4.98G [01:12<04:08, 17.2MB/s]
# Downloading waveforms:  20%|██        | 1.01G/4.98G [01:12<04:15, 16.7MB/s]
# Downloading waveforms:  20%|██        | 1.01G/4.98G [01:12<04:16, 16.7MB/s]
# Downloading waveforms:  20%|██        | 1.01G/4.98G [01:12<04:48, 14.8MB/s]
# Downloading waveforms:  20%|██        | 1.01G/4.98G [01:12<04:23, 16.1MB/s]
# Downloading waveforms:  20%|██        | 1.01G/4.98G [01:12<04:11, 16.9MB/s]
# Downloading waveforms:  20%|██        | 1.02G/4.98G [01:13<05:04, 14.0MB/s]
# Downloading waveforms:  20%|██        | 1.02G/4.98G [01:13<03:35, 19.7MB/s]
# Downloading waveforms:  21%|██        | 1.02G/4.98G [01:13<04:17, 16.5MB/s]
# Downloading waveforms:  21%|██        | 1.02G/4.98G [01:13<04:54, 14.4MB/s]
# Downloading waveforms:  21%|██        | 1.03G/4.98G [01:13<03:45, 18.8MB/s]
# Downloading waveforms:  21%|██        | 1.03G/4.98G [01:13<04:21, 16.2MB/s]
# Downloading waveforms:  21%|██        | 1.03G/4.98G [01:13<04:55, 14.4MB/s]
# Downloading waveforms:  21%|██        | 1.03G/4.98G [01:14<03:54, 18.1MB/s]
# Downloading waveforms:  21%|██        | 1.04G/4.98G [01:14<04:26, 15.9MB/s]
# Downloading waveforms:  21%|██        | 1.04G/4.98G [01:14<05:10, 13.6MB/s]
# Downloading waveforms:  21%|██        | 1.04G/4.98G [01:14<03:53, 18.1MB/s]
# Downloading waveforms:  21%|██        | 1.04G/4.98G [01:14<04:32, 15.5MB/s]
# Downloading waveforms:  21%|██        | 1.04G/4.98G [01:14<05:06, 13.8MB/s]
# Downloading waveforms:  21%|██        | 1.05G/4.98G [01:15<04:00, 17.5MB/s]
# Downloading waveforms:  21%|██        | 1.05G/4.98G [01:15<04:27, 15.8MB/s]
# Downloading waveforms:  21%|██        | 1.05G/4.98G [01:15<05:04, 13.8MB/s]
# Downloading waveforms:  21%|██        | 1.05G/4.98G [01:15<04:02, 17.4MB/s]
# Downloading waveforms:  21%|██        | 1.06G/4.98G [01:15<04:28, 15.7MB/s]
# Downloading waveforms:  21%|██▏       | 1.06G/4.98G [01:15<04:55, 14.2MB/s]
# Downloading waveforms:  21%|██▏       | 1.06G/4.98G [01:15<04:18, 16.3MB/s]
# Downloading waveforms:  21%|██▏       | 1.06G/4.98G [01:16<04:45, 14.7MB/s]
# Downloading waveforms:  21%|██▏       | 1.07G/4.98G [01:16<04:48, 14.6MB/s]
# Downloading waveforms:  21%|██▏       | 1.07G/4.98G [01:16<04:05, 17.1MB/s]
# Downloading waveforms:  21%|██▏       | 1.07G/4.98G [01:16<04:35, 15.2MB/s]
# Downloading waveforms:  22%|██▏       | 1.07G/4.98G [01:16<04:49, 14.5MB/s]
# Downloading waveforms:  22%|██▏       | 1.08G/4.98G [01:16<04:03, 17.2MB/s]
# Downloading waveforms:  22%|██▏       | 1.08G/4.98G [01:17<04:33, 15.3MB/s]
# Downloading waveforms:  22%|██▏       | 1.08G/4.98G [01:17<04:36, 15.1MB/s]
# Downloading waveforms:  22%|██▏       | 1.08G/4.98G [01:17<04:20, 16.1MB/s]
# Downloading waveforms:  22%|██▏       | 1.08G/4.98G [01:17<04:33, 15.3MB/s]
# Downloading waveforms:  22%|██▏       | 1.08G/4.98G [01:17<04:28, 15.6MB/s]
# Downloading waveforms:  22%|██▏       | 1.09G/4.98G [01:17<04:38, 15.0MB/s]
# Downloading waveforms:  22%|██▏       | 1.09G/4.98G [01:17<04:23, 15.8MB/s]
# Downloading waveforms:  22%|██▏       | 1.09G/4.98G [01:18<04:25, 15.7MB/s]
# Downloading waveforms:  22%|██▏       | 1.09G/4.98G [01:18<04:23, 15.9MB/s]
# Downloading waveforms:  22%|██▏       | 1.09G/4.98G [01:18<04:22, 15.9MB/s]
# Downloading waveforms:  22%|██▏       | 1.10G/4.98G [01:18<04:15, 16.3MB/s]
# Downloading waveforms:  22%|██▏       | 1.10G/4.98G [01:18<04:17, 16.2MB/s]
# Downloading waveforms:  22%|██▏       | 1.10G/4.98G [01:18<04:22, 15.9MB/s]
# Downloading waveforms:  22%|██▏       | 1.10G/4.98G [01:18<05:03, 13.7MB/s]
# Downloading waveforms:  22%|██▏       | 1.10G/4.98G [01:18<03:44, 18.5MB/s]
# Downloading waveforms:  22%|██▏       | 1.11G/4.98G [01:19<04:26, 15.6MB/s]
# Downloading waveforms:  22%|██▏       | 1.11G/4.98G [01:19<04:52, 14.2MB/s]
# Downloading waveforms:  22%|██▏       | 1.11G/4.98G [01:19<03:57, 17.5MB/s]
# Downloading waveforms:  22%|██▏       | 1.11G/4.98G [01:19<04:23, 15.7MB/s]
# Downloading waveforms:  22%|██▏       | 1.11G/4.98G [01:19<04:49, 14.3MB/s]
# Downloading waveforms:  22%|██▏       | 1.12G/4.98G [01:19<04:03, 17.0MB/s]
# Downloading waveforms:  22%|██▏       | 1.12G/4.98G [01:20<04:29, 15.4MB/s]
# Downloading waveforms:  23%|██▎       | 1.12G/4.98G [01:20<03:56, 17.5MB/s]
# Downloading waveforms:  23%|██▎       | 1.12G/4.98G [01:20<04:39, 14.8MB/s]
# Downloading waveforms:  23%|██▎       | 1.13G/4.98G [01:20<04:55, 14.0MB/s]
# Downloading waveforms:  23%|██▎       | 1.13G/4.98G [01:20<03:59, 17.3MB/s]
# Downloading waveforms:  23%|██▎       | 1.13G/4.98G [01:20<04:25, 15.6MB/s]
# Downloading waveforms:  23%|██▎       | 1.13G/4.98G [01:20<05:05, 13.5MB/s]
# Downloading waveforms:  23%|██▎       | 1.13G/4.98G [01:21<04:03, 16.9MB/s]
# Downloading waveforms:  23%|██▎       | 1.14G/4.98G [01:21<04:25, 15.5MB/s]
# Downloading waveforms:  23%|██▎       | 1.14G/4.98G [01:21<04:53, 14.0MB/s]
# Downloading waveforms:  23%|██▎       | 1.14G/4.98G [01:21<04:09, 16.5MB/s]
# Downloading waveforms:  23%|██▎       | 1.14G/4.98G [01:21<04:32, 15.1MB/s]
# Downloading waveforms:  23%|██▎       | 1.15G/4.98G [01:21<04:04, 16.9MB/s]
# Downloading waveforms:  23%|██▎       | 1.15G/4.98G [01:21<04:24, 15.6MB/s]
# Downloading waveforms:  23%|██▎       | 1.15G/4.98G [01:22<04:50, 14.2MB/s]
# Downloading waveforms:  23%|██▎       | 1.15G/4.98G [01:22<04:22, 15.7MB/s]
# Downloading waveforms:  23%|██▎       | 1.15G/4.98G [01:22<04:56, 13.9MB/s]
# Downloading waveforms:  23%|██▎       | 1.16G/4.98G [01:22<03:52, 17.7MB/s]
# Downloading waveforms:  23%|██▎       | 1.16G/4.98G [01:22<04:21, 15.7MB/s]
# Downloading waveforms:  23%|██▎       | 1.16G/4.98G [01:22<04:41, 14.6MB/s]
# Downloading waveforms:  23%|██▎       | 1.16G/4.98G [01:22<04:24, 15.5MB/s]
# Downloading waveforms:  23%|██▎       | 1.16G/4.98G [01:23<04:48, 14.2MB/s]
# Downloading waveforms:  23%|██▎       | 1.17G/4.98G [01:23<04:11, 16.3MB/s]
# Downloading waveforms:  23%|██▎       | 1.17G/4.98G [01:23<04:37, 14.8MB/s]
# Downloading waveforms:  23%|██▎       | 1.17G/4.98G [01:23<03:48, 17.9MB/s]
# Downloading waveforms:  24%|██▎       | 1.17G/4.98G [01:23<04:19, 15.8MB/s]
# Downloading waveforms:  24%|██▎       | 1.17G/4.98G [01:23<04:57, 13.7MB/s]
# Downloading waveforms:  24%|██▎       | 1.18G/4.98G [01:23<04:18, 15.8MB/s]
# Downloading waveforms:  24%|██▎       | 1.18G/4.98G [01:24<04:41, 14.5MB/s]
# Downloading waveforms:  24%|██▎       | 1.18G/4.98G [01:24<04:03, 16.8MB/s]
# Downloading waveforms:  24%|██▎       | 1.18G/4.98G [01:24<04:34, 14.9MB/s]
# Downloading waveforms:  24%|██▍       | 1.18G/4.98G [01:24<04:47, 14.2MB/s]
# Downloading waveforms:  24%|██▍       | 1.19G/4.98G [01:24<04:01, 16.9MB/s]
# ...
# Downloading waveforms:  91%|█████████ | 4.51G/4.98G [05:19<00:28, 18.0MB/s]
# Downloading waveforms:  91%|█████████ | 4.51G/4.98G [05:20<00:31, 16.2MB/s]
# Downloading waveforms:  91%|█████████ | 4.51G/4.98G [05:20<00:37, 13.5MB/s]
# Downloading waveforms:  91%|█████████ | 4.51G/4.98G [05:20<00:28, 17.6MB/s]
# Downloading waveforms:  91%|█████████ | 4.52G/4.98G [05:20<00:31, 15.7MB/s]
# Downloading waveforms:  91%|█████████ | 4.52G/4.98G [05:20<00:35, 13.9MB/s]
# Downloading waveforms:  91%|█████████ | 4.52G/4.98G [05:20<00:29, 16.8MB/s]
# Downloading waveforms:  91%|█████████ | 4.52G/4.98G [05:20<00:31, 15.3MB/s]
# Downloading waveforms:  91%|█████████ | 4.53G/4.98G [05:21<00:33, 14.5MB/s]
# Downloading waveforms:  91%|█████████ | 4.53G/4.98G [05:21<00:29, 16.6MB/s]
# Downloading waveforms:  91%|█████████ | 4.53G/4.98G [05:21<00:32, 14.8MB/s]
# Downloading waveforms:  91%|█████████ | 4.53G/4.98G [05:21<00:32, 14.6MB/s]
# Downloading waveforms:  91%|█████████ | 4.54G/4.98G [05:21<00:31, 15.3MB/s]
# Downloading waveforms:  91%|█████████ | 4.54G/4.98G [05:22<00:26, 17.6MB/s]
# Downloading waveforms:  91%|█████████ | 4.54G/4.98G [05:22<00:29, 15.9MB/s]
# Downloading waveforms:  91%|█████████ | 4.54G/4.98G [05:22<00:32, 14.6MB/s]
# Downloading waveforms:  91%|█████████▏| 4.55G/4.98G [05:22<00:26, 17.8MB/s]
# Downloading waveforms:  91%|█████████▏| 4.55G/4.98G [05:22<00:28, 16.3MB/s]
# Downloading waveforms:  91%|█████████▏| 4.55G/4.98G [05:22<00:32, 14.3MB/s]
# Downloading waveforms:  91%|█████████▏| 4.55G/4.98G [05:22<00:26, 17.5MB/s]
# Downloading waveforms:  91%|█████████▏| 4.55G/4.98G [05:23<00:28, 16.0MB/s]
# Downloading waveforms:  92%|█████████▏| 4.56G/4.98G [05:23<00:31, 14.5MB/s]
# Downloading waveforms:  92%|█████████▏| 4.56G/4.98G [05:23<00:26, 16.7MB/s]
# Downloading waveforms:  92%|█████████▏| 4.56G/4.98G [05:23<00:29, 15.3MB/s]
# Downloading waveforms:  92%|█████████▏| 4.56G/4.98G [05:23<00:24, 18.4MB/s]
# Downloading waveforms:  92%|█████████▏| 4.57G/4.98G [05:23<00:29, 15.2MB/s]
# Downloading waveforms:  92%|█████████▏| 4.57G/4.98G [05:24<00:31, 14.0MB/s]
# Downloading waveforms:  92%|█████████▏| 4.57G/4.98G [05:24<00:26, 16.7MB/s]
# Downloading waveforms:  92%|█████████▏| 4.57G/4.98G [05:24<00:28, 15.2MB/s]
# Downloading waveforms:  92%|█████████▏| 4.57G/4.98G [05:24<00:30, 14.2MB/s]
# Downloading waveforms:  92%|█████████▏| 4.58G/4.98G [05:24<00:25, 17.0MB/s]
# Downloading waveforms:  92%|█████████▏| 4.58G/4.98G [05:24<00:27, 15.6MB/s]
# Downloading waveforms:  92%|█████████▏| 4.58G/4.98G [05:25<00:29, 14.5MB/s]
# Downloading waveforms:  92%|█████████▏| 4.58G/4.98G [05:25<00:24, 17.2MB/s]
# Downloading waveforms:  92%|█████████▏| 4.59G/4.98G [05:25<00:26, 15.8MB/s]
# Downloading waveforms:  92%|█████████▏| 4.59G/4.98G [05:25<00:28, 14.6MB/s]
# Downloading waveforms:  92%|█████████▏| 4.59G/4.98G [05:25<00:24, 16.8MB/s]
# Downloading waveforms:  92%|█████████▏| 4.59G/4.98G [05:25<00:27, 15.4MB/s]
# Downloading waveforms:  92%|█████████▏| 4.59G/4.98G [05:25<00:24, 17.2MB/s]
# Downloading waveforms:  92%|█████████▏| 4.60G/4.98G [05:26<00:26, 15.4MB/s]
# Downloading waveforms:  92%|█████████▏| 4.60G/4.98G [05:26<00:27, 14.9MB/s]
# Downloading waveforms:  92%|█████████▏| 4.60G/4.98G [05:26<00:26, 15.4MB/s]
# Downloading waveforms:  92%|█████████▏| 4.60G/4.98G [05:26<00:26, 15.4MB/s]
# Downloading waveforms:  92%|█████████▏| 4.60G/4.98G [05:26<00:26, 15.4MB/s]
# Downloading waveforms:  92%|█████████▏| 4.61G/4.98G [05:26<00:26, 15.0MB/s]
# Downloading waveforms:  93%|█████████▎| 4.61G/4.98G [05:26<00:25, 15.7MB/s]
# Downloading waveforms:  93%|█████████▎| 4.61G/4.98G [05:26<00:28, 13.8MB/s]
# Downloading waveforms:  93%|█████████▎| 4.61G/4.98G [05:27<00:22, 17.3MB/s]
# Downloading waveforms:  93%|█████████▎| 4.61G/4.98G [05:27<00:25, 15.5MB/s]
# Downloading waveforms:  93%|█████████▎| 4.62G/4.98G [05:27<00:21, 18.0MB/s]
# Downloading waveforms:  93%|█████████▎| 4.62G/4.98G [05:27<00:24, 16.2MB/s]
# Downloading waveforms:  93%|█████████▎| 4.62G/4.98G [05:27<00:28, 13.8MB/s]
# Downloading waveforms:  93%|█████████▎| 4.62G/4.98G [05:27<00:23, 16.2MB/s]
# Downloading waveforms:  93%|█████████▎| 4.62G/4.98G [05:27<00:25, 15.0MB/s]
# Downloading waveforms:  93%|█████████▎| 4.63G/4.98G [05:27<00:22, 17.2MB/s]
# Downloading waveforms:  93%|█████████▎| 4.63G/4.98G [05:28<00:24, 15.4MB/s]
# Downloading waveforms:  93%|█████████▎| 4.63G/4.98G [05:28<00:26, 14.2MB/s]
# Downloading waveforms:  93%|█████████▎| 4.63G/4.98G [05:28<00:22, 16.6MB/s]
# Downloading waveforms:  93%|█████████▎| 4.63G/4.98G [05:28<00:24, 15.1MB/s]
# Downloading waveforms:  93%|█████████▎| 4.64G/4.98G [05:28<00:25, 14.3MB/s]
# Downloading waveforms:  93%|█████████▎| 4.64G/4.98G [05:28<00:21, 17.3MB/s]
# Downloading waveforms:  93%|█████████▎| 4.64G/4.98G [05:29<00:23, 15.6MB/s]
# Downloading waveforms:  93%|█████████▎| 4.64G/4.98G [05:29<00:20, 17.9MB/s]
# Downloading waveforms:  93%|█████████▎| 4.65G/4.98G [05:29<00:23, 15.0MB/s]
# Downloading waveforms:  93%|█████████▎| 4.65G/4.98G [05:29<00:25, 14.0MB/s]
# Downloading waveforms:  93%|█████████▎| 4.65G/4.98G [05:29<00:21, 16.6MB/s]
# Downloading waveforms:  93%|█████████▎| 4.65G/4.98G [05:29<00:23, 15.0MB/s]
# Downloading waveforms:  93%|█████████▎| 4.65G/4.98G [05:29<00:18, 18.6MB/s]
# Downloading waveforms:  94%|█████████▎| 4.66G/4.98G [05:30<00:23, 15.1MB/s]
# Downloading waveforms:  94%|█████████▎| 4.66G/4.98G [05:30<00:24, 14.2MB/s]
# Downloading waveforms:  94%|█████████▎| 4.66G/4.98G [05:30<00:20, 16.7MB/s]
# Downloading waveforms:  94%|█████████▎| 4.66G/4.98G [05:30<00:22, 15.2MB/s]
# Downloading waveforms:  94%|█████████▎| 4.66G/4.98G [05:30<00:23, 14.2MB/s]
# Downloading waveforms:  94%|█████████▎| 4.67G/4.98G [05:30<00:19, 16.9MB/s]
# Downloading waveforms:  94%|█████████▍| 4.67G/4.98G [05:31<00:21, 15.6MB/s]
# Downloading waveforms:  94%|█████████▍| 4.67G/4.98G [05:31<00:18, 18.2MB/s]
# Downloading waveforms:  94%|█████████▍| 4.67G/4.98G [05:31<00:22, 14.9MB/s]
# Downloading waveforms:  94%|█████████▍| 4.68G/4.98G [05:31<00:22, 14.2MB/s]
# Downloading waveforms:  94%|█████████▍| 4.68G/4.98G [05:31<00:20, 15.9MB/s]
# Downloading waveforms:  94%|█████████▍| 4.68G/4.98G [05:31<00:21, 14.9MB/s]
# Downloading waveforms:  94%|█████████▍| 4.68G/4.98G [05:31<00:18, 17.7MB/s]
# Downloading waveforms:  94%|█████████▍| 4.68G/4.98G [05:31<00:20, 15.6MB/s]
# Downloading waveforms:  94%|█████████▍| 4.69G/4.98G [05:32<00:22, 13.8MB/s]
# Downloading waveforms:  94%|█████████▍| 4.69G/4.98G [05:32<00:19, 16.4MB/s]
# Downloading waveforms:  94%|█████████▍| 4.69G/4.98G [05:32<00:20, 14.9MB/s]
# Downloading waveforms:  94%|█████████▍| 4.69G/4.98G [05:32<00:17, 17.7MB/s]
# Downloading waveforms:  94%|█████████▍| 4.69G/4.98G [05:32<00:19, 15.7MB/s]
# Downloading waveforms:  94%|█████████▍| 4.70G/4.98G [05:32<00:21, 14.2MB/s]
# Downloading waveforms:  94%|█████████▍| 4.70G/4.98G [05:33<00:17, 16.9MB/s]
# Downloading waveforms:  94%|█████████▍| 4.70G/4.98G [05:33<00:19, 15.3MB/s]
# Downloading waveforms:  94%|█████████▍| 4.70G/4.98G [05:33<00:17, 17.2MB/s]
# Downloading waveforms:  94%|█████████▍| 4.70G/4.98G [05:33<00:19, 15.5MB/s]
# Downloading waveforms:  95%|█████████▍| 4.71G/4.98G [05:33<00:20, 14.6MB/s]
# Downloading waveforms:  95%|█████████▍| 4.71G/4.98G [05:33<00:18, 16.1MB/s]
# Downloading waveforms:  95%|█████████▍| 4.71G/4.98G [05:33<00:19, 14.6MB/s]
# Downloading waveforms:  95%|█████████▍| 4.71G/4.98G [05:33<00:16, 17.7MB/s]
# Downloading waveforms:  95%|█████████▍| 4.71G/4.98G [05:34<00:17, 16.1MB/s]
# Downloading waveforms:  95%|█████████▍| 4.72G/4.98G [05:34<00:17, 16.6MB/s]
# Downloading waveforms:  95%|█████████▍| 4.72G/4.98G [05:34<00:18, 15.0MB/s]
# Downloading waveforms:  95%|█████████▍| 4.72G/4.98G [05:34<00:19, 14.2MB/s]
# Downloading waveforms:  95%|█████████▍| 4.72G/4.98G [05:34<00:16, 16.8MB/s]
# Downloading waveforms:  95%|█████████▍| 4.72G/4.98G [05:34<00:18, 14.9MB/s]
# Downloading waveforms:  95%|█████████▍| 4.73G/4.98G [05:34<00:15, 17.8MB/s]
# Downloading waveforms:  95%|█████████▍| 4.73G/4.98G [05:35<00:16, 16.2MB/s]
# Downloading waveforms:  95%|█████████▌| 4.73G/4.98G [05:35<00:19, 14.0MB/s]
# Downloading waveforms:  95%|█████████▌| 4.73G/4.98G [05:35<00:15, 16.6MB/s]
# Downloading waveforms:  95%|█████████▌| 4.74G/4.98G [05:35<00:17, 15.3MB/s]
# Downloading waveforms:  95%|█████████▌| 4.74G/4.98G [05:35<00:14, 17.6MB/s]
# Downloading waveforms:  95%|█████████▌| 4.74G/4.98G [05:35<00:16, 15.7MB/s]
# Downloading waveforms:  95%|█████████▌| 4.74G/4.98G [05:36<00:18, 14.1MB/s]
# Downloading waveforms:  95%|█████████▌| 4.74G/4.98G [05:36<00:15, 16.3MB/s]
# Downloading waveforms:  95%|█████████▌| 4.75G/4.98G [05:36<00:16, 15.0MB/s]
# Downloading waveforms:  95%|█████████▌| 4.75G/4.98G [05:36<00:14, 17.1MB/s]
# Downloading waveforms:  95%|█████████▌| 4.75G/4.98G [05:36<00:15, 15.5MB/s]
# Downloading waveforms:  95%|█████████▌| 4.75G/4.98G [05:36<00:16, 15.0MB/s]
# Downloading waveforms:  95%|█████████▌| 4.75G/4.98G [05:36<00:15, 15.3MB/s]
# Downloading waveforms:  96%|█████████▌| 4.76G/4.98G [05:36<00:16, 14.6MB/s]
# Downloading waveforms:  96%|█████████▌| 4.76G/4.98G [05:37<00:13, 17.1MB/s]
# Downloading waveforms:  96%|█████████▌| 4.76G/4.98G [05:37<00:15, 15.6MB/s]
# Downloading waveforms:  96%|█████████▌| 4.76G/4.98G [05:37<00:13, 17.5MB/s]
# Downloading waveforms:  96%|█████████▌| 4.76G/4.98G [05:37<00:15, 15.4MB/s]
# Downloading waveforms:  96%|█████████▌| 4.77G/4.98G [05:37<00:16, 14.0MB/s]
# Downloading waveforms:  96%|█████████▌| 4.77G/4.98G [05:37<00:13, 16.6MB/s]
# Downloading waveforms:  96%|█████████▌| 4.77G/4.98G [05:37<00:14, 15.1MB/s]
# Downloading waveforms:  96%|█████████▌| 4.77G/4.98G [05:38<00:15, 14.4MB/s]
# Downloading waveforms:  96%|█████████▌| 4.78G/4.98G [05:38<00:12, 17.0MB/s]
# Downloading waveforms:  96%|█████████▌| 4.78G/4.98G [05:38<00:14, 15.3MB/s]
# Downloading waveforms:  96%|█████████▌| 4.78G/4.98G [05:38<00:14, 14.4MB/s]
# Downloading waveforms:  96%|█████████▌| 4.78G/4.98G [05:38<00:12, 16.7MB/s]
# Downloading waveforms:  96%|█████████▌| 4.78G/4.98G [05:38<00:13, 15.4MB/s]
# Downloading waveforms:  96%|█████████▌| 4.79G/4.98G [05:38<00:11, 18.4MB/s]
# Downloading waveforms:  96%|█████████▌| 4.79G/4.98G [05:39<00:12, 16.2MB/s]
# Downloading waveforms:  96%|█████████▌| 4.79G/4.98G [05:39<00:14, 13.8MB/s]
# Downloading waveforms:  96%|█████████▋| 4.79G/4.98G [05:39<00:11, 17.1MB/s]
# Downloading waveforms:  96%|█████████▋| 4.80G/4.98G [05:39<00:13, 14.9MB/s]
# Downloading waveforms:  96%|█████████▋| 4.80G/4.98G [05:39<00:12, 15.9MB/s]
# Downloading waveforms:  96%|█████████▋| 4.80G/4.98G [05:39<00:12, 15.3MB/s]
# Downloading waveforms:  96%|█████████▋| 4.80G/4.98G [05:40<00:14, 13.5MB/s]
# Downloading waveforms:  96%|█████████▋| 4.80G/4.98G [05:40<00:10, 17.6MB/s]
# Downloading waveforms:  97%|█████████▋| 4.81G/4.98G [05:40<00:12, 15.5MB/s]
# Downloading waveforms:  97%|█████████▋| 4.81G/4.98G [05:40<00:13, 13.9MB/s]
# Downloading waveforms:  97%|█████████▋| 4.81G/4.98G [05:40<00:10, 17.6MB/s]
# Downloading waveforms:  97%|█████████▋| 4.81G/4.98G [05:40<00:11, 15.8MB/s]
# Downloading waveforms:  97%|█████████▋| 4.82G/4.98G [05:41<00:12, 13.9MB/s]
# Downloading waveforms:  97%|█████████▋| 4.82G/4.98G [05:41<00:09, 18.1MB/s]
# Downloading waveforms:  97%|█████████▋| 4.82G/4.98G [05:41<00:10, 15.6MB/s]
# Downloading waveforms:  97%|█████████▋| 4.82G/4.98G [05:41<00:12, 13.9MB/s]
# Downloading waveforms:  97%|█████████▋| 4.83G/4.98G [05:41<00:11, 14.8MB/s]
# Downloading waveforms:  97%|█████████▋| 4.83G/4.98G [05:41<00:08, 18.5MB/s]
# Downloading waveforms:  97%|█████████▋| 4.83G/4.98G [05:42<00:10, 15.4MB/s]
# Downloading waveforms:  97%|█████████▋| 4.83G/4.98G [05:42<00:11, 14.2MB/s]
# Downloading waveforms:  97%|█████████▋| 4.84G/4.98G [05:42<00:10, 14.5MB/s]
# Downloading waveforms:  97%|█████████▋| 4.84G/4.98G [05:42<00:10, 14.1MB/s]
# Downloading waveforms:  97%|█████████▋| 4.84G/4.98G [05:42<00:11, 12.9MB/s]
# Downloading waveforms:  97%|█████████▋| 4.84G/4.98G [05:43<00:11, 12.7MB/s]
# Downloading waveforms:  97%|█████████▋| 4.84G/4.98G [05:43<00:11, 12.6MB/s]
# Downloading waveforms:  97%|█████████▋| 4.85G/4.98G [05:43<00:11, 12.8MB/s]
# Downloading waveforms:  97%|█████████▋| 4.85G/4.98G [05:43<00:10, 13.0MB/s]
# Downloading waveforms:  97%|█████████▋| 4.85G/4.98G [05:43<00:10, 13.0MB/s]
# Downloading waveforms:  98%|█████████▊| 4.86G/4.98G [05:44<00:09, 13.3MB/s]
# Downloading waveforms:  98%|█████████▊| 4.86G/4.98G [05:44<00:09, 13.7MB/s]
# Downloading waveforms:  98%|█████████▊| 4.86G/4.98G [05:44<00:09, 13.5MB/s]
# Downloading waveforms:  98%|█████████▊| 4.87G/4.98G [05:44<00:06, 17.5MB/s]
# Downloading waveforms:  98%|█████████▊| 4.87G/4.98G [05:44<00:07, 15.2MB/s]
# Downloading waveforms:  98%|█████████▊| 4.87G/4.98G [05:45<00:08, 13.5MB/s]
# Downloading waveforms:  98%|█████████▊| 4.87G/4.98G [05:45<00:09, 12.4MB/s]
# Downloading waveforms:  98%|█████████▊| 4.87G/4.98G [05:45<00:07, 15.4MB/s]
# Downloading waveforms:  98%|█████████▊| 4.88G/4.98G [05:45<00:07, 14.2MB/s]
# Downloading waveforms:  98%|█████████▊| 4.88G/4.98G [05:45<00:08, 12.4MB/s]
# Downloading waveforms:  98%|█████████▊| 4.88G/4.98G [05:46<00:08, 12.5MB/s]
# Downloading waveforms:  98%|█████████▊| 4.88G/4.98G [05:46<00:07, 13.2MB/s]
# Downloading waveforms:  98%|█████████▊| 4.89G/4.98G [05:46<00:07, 14.1MB/s]
# Downloading waveforms:  98%|█████████▊| 4.89G/4.98G [05:46<00:06, 14.7MB/s]
# Downloading waveforms:  98%|█████████▊| 4.89G/4.98G [05:47<00:06, 15.0MB/s]
# Downloading waveforms:  98%|█████████▊| 4.90G/4.98G [05:47<00:05, 15.2MB/s]
# Downloading waveforms:  98%|█████████▊| 4.90G/4.98G [05:47<00:05, 15.4MB/s]
# Downloading waveforms:  98%|█████████▊| 4.90G/4.98G [05:47<00:04, 18.3MB/s]
# Downloading waveforms:  99%|█████████▊| 4.91G/4.98G [05:47<00:04, 16.1MB/s]
# Downloading waveforms:  99%|█████████▊| 4.91G/4.98G [05:47<00:05, 14.6MB/s]
# Downloading waveforms:  99%|█████████▊| 4.91G/4.98G [05:48<00:04, 16.2MB/s]
# Downloading waveforms:  99%|█████████▊| 4.91G/4.98G [05:48<00:04, 15.0MB/s]
# Downloading waveforms:  99%|█████████▊| 4.91G/4.98G [05:48<00:05, 13.5MB/s]
# Downloading waveforms:  99%|█████████▊| 4.92G/4.98G [05:48<00:05, 13.0MB/s]
# Downloading waveforms:  99%|█████████▉| 4.92G/4.98G [05:48<00:04, 13.4MB/s]
# Downloading waveforms:  99%|█████████▉| 4.92G/4.98G [05:49<00:04, 13.9MB/s]
# Downloading waveforms:  99%|█████████▉| 4.93G/4.98G [05:49<00:04, 14.2MB/s]
# Downloading waveforms:  99%|█████████▉| 4.93G/4.98G [05:49<00:03, 14.3MB/s]
# Downloading waveforms:  99%|█████████▉| 4.93G/4.98G [05:49<00:03, 13.9MB/s]
# Downloading waveforms:  99%|█████████▉| 4.94G/4.98G [05:49<00:02, 17.5MB/s]
# Downloading waveforms:  99%|█████████▉| 4.94G/4.98G [05:50<00:03, 15.0MB/s]
# Downloading waveforms:  99%|█████████▉| 4.94G/4.98G [05:50<00:03, 13.2MB/s]
# Downloading waveforms:  99%|█████████▉| 4.94G/4.98G [05:50<00:03, 12.8MB/s]
# Downloading waveforms:  99%|█████████▉| 4.94G/4.98G [05:50<00:02, 13.3MB/s]
# Downloading waveforms:  99%|█████████▉| 4.95G/4.98G [05:50<00:02, 13.3MB/s]
# Downloading waveforms:  99%|█████████▉| 4.95G/4.98G [05:51<00:02, 14.0MB/s]
# Downloading waveforms:  99%|█████████▉| 4.95G/4.98G [05:51<00:01, 14.3MB/s]
# Downloading waveforms: 100%|█████████▉| 4.96G/4.98G [05:51<00:01, 13.5MB/s]
# Downloading waveforms: 100%|█████████▉| 4.96G/4.98G [05:51<00:01, 17.3MB/s]
# Downloading waveforms: 100%|█████████▉| 4.96G/4.98G [05:51<00:01, 14.5MB/s]
# Downloading waveforms: 100%|█████████▉| 4.96G/4.98G [05:52<00:01, 14.3MB/s]
# Downloading waveforms: 100%|█████████▉| 4.96G/4.98G [05:52<00:01, 15.1MB/s]
# Downloading waveforms: 100%|█████████▉| 4.97G/4.98G [05:52<00:00, 14.3MB/s]
# Downloading waveforms: 100%|█████████▉| 4.97G/4.98G [05:52<00:00, 16.2MB/s]
# Downloading waveforms: 100%|█████████▉| 4.97G/4.98G [05:52<00:00, 13.0MB/s]
# Downloading waveforms: 100%|█████████▉| 4.97G/4.98G [05:52<00:00, 12.6MB/s]
# Downloading waveforms: 100%|█████████▉| 4.98G/4.98G [05:52<00:00, 16.9MB/s]
# Downloading waveforms: 100%|█████████▉| 4.98G/4.98G [05:53<00:00, 14.2MB/s]
# Downloading waveforms: 100%|██████████| 4.98G/4.98G [05:53<00:00, 15.1MB/s]
# 2025-07-12 16:40:19,990 | seisbench | WARNING | Output component order not specified, defaulting to 'ZNE'.
# WARNING:seisbench:Output component order not specified, defaulting to 'ZNE'.

# %% [markdown]
# ## Generation pipeline

# %% [markdown]
# The ETHZ dataset contains detailed labels for the phases. However, for this example we only want to differentiate between P and S picks. Therefore, we define a dictionary mapping the detailed picks to their phases.

# %%
phase_dict = {
    "trace_p_arrival_sample": "P",
    "trace_pP_arrival_sample": "P",
    "trace_P_arrival_sample": "P",
    "trace_P1_arrival_sample": "P",
    "trace_Pg_arrival_sample": "P",
    "trace_Pn_arrival_sample": "P",
    "trace_PmP_arrival_sample": "P",
    "trace_pwP_arrival_sample": "P",
    "trace_pwPm_arrival_sample": "P",
    "trace_s_arrival_sample": "S",
    "trace_S_arrival_sample": "S",
    "trace_S1_arrival_sample": "S",
    "trace_Sg_arrival_sample": "S",
    "trace_SmS_arrival_sample": "S",
    "trace_Sn_arrival_sample": "S",
}

# %% [markdown]
# Now we define two generators with identical augmentations, one for training, one for validation. The augmentations are:
# 1. Selection of a (long) window around a pick. This way, we ensure that out data always contains a pick.
# 1. Selection of a random window with 3001 samples, the input length of PhaseNet.
# 1. A change of datatype to float32, as this is expected by the pytorch model.
# 1. A probabilistic label
#
# Note that we do no normalization here. This will be done directly in the training lood with a builtin function of the model.

# %%
train_generator = sbg.GenericGenerator(train)
dev_generator = sbg.GenericGenerator(dev)

augmentations = [
    sbg.WindowAroundSample(list(phase_dict.keys()), samples_before=3000, windowlen=6000, selection="random", strategy="variable"),
    sbg.RandomWindow(windowlen=3001, strategy="pad"),
    sbg.ChangeDtype(np.float32),
    sbg.ProbabilisticLabeller(label_columns=phase_dict, model_labels=model.labels, sigma=30, dim=0)
]

train_generator.add_augmentations(augmentations)
dev_generator.add_augmentations(augmentations)

# %% [markdown]
# Let's visualize a few training examples. Everytime you run the cell below, you'll see a different training example.

# %%
sample = train_generator[np.random.randint(len(train_generator))]

fig = plt.figure(figsize=(15, 10))
axs = fig.subplots(2, 1, sharex=True, gridspec_kw={"hspace": 0, "height_ratios": [3, 1]})
axs[0].plot(sample["X"].T)
axs[1].plot(sample["y"].T)
# Out:
# [<matplotlib.lines.Line2D at 0x79b83733b690>,
#  <matplotlib.lines.Line2D at 0x79b83733b910>,
#  <matplotlib.lines.Line2D at 0x79b837353f50>]

# %% [markdown]
# SeisBench generators are pytorch datasets. Therefore, we can pass them to pytorch data loaders. These will automatically take care of parallel loading and batching. Here we create one loader for training and one for validation. We choose a batch size of 256 samples. This batch size should fit on most hardware.

# %%
batch_size = 256
num_workers = 4  # The number of threads used for loading data

train_loader = DataLoader(train_generator, batch_size=batch_size, shuffle=True, num_workers=num_workers, worker_init_fn=worker_seeding)
dev_loader = DataLoader(dev_generator, batch_size=batch_size, shuffle=False, num_workers=num_workers, worker_init_fn=worker_seeding)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %% [markdown]
# ## Training a model

# %% [markdown]
# Now we got all components for training the model. What we still need to do is define the optimizer and the loss, and write the training and validation loops.

# %%
learning_rate = 1e-2
epochs = 5

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

def loss_fn(y_pred, y_true, eps=1e-5):
    # vector cross entropy loss
    h = y_true * torch.log(y_pred + eps)
    h = h.mean(-1).sum(-1)  # Mean along sample dimension and sum along pick dimension
    h = h.mean()  # Mean over batch axis
    return -h

# %%
def train_loop(dataloader):
    size = len(dataloader.dataset)
    for batch_id, batch in enumerate(dataloader):
        # Compute prediction and loss
        x = batch["X"].to(model.device)
        x_preproc = model.annotate_batch_pre(x, {})  # Remove mean and normalize amplitude
        pred = model(x_preproc)
        loss = loss_fn(pred, batch["y"].to(model.device))

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch_id % 5 == 0:
            loss, current = loss.item(), batch_id * batch["X"].shape[0]
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")


def test_loop(dataloader):
    num_batches = len(dataloader)
    test_loss = 0

    model.eval()  # close the model for evaluation

    with torch.no_grad():
        for batch in dataloader:
            x = batch["X"].to(model.device)
            x_preproc = model.annotate_batch_pre(x, {})  # Remove mean and normalize amplitude
            pred = model(x_preproc)
            test_loss += loss_fn(pred, batch["y"].to(model.device)).item()

    model.train()  # re-open model for training stage

    test_loss /= num_batches
    print(f"Test avg loss: {test_loss:>8f} \n")

# %% [markdown]
# *Note:* Depending on your hardware, this step might take a few minutes. We've set a low number of epochs to reduce runtime, but it might still take 5 to 20 minutes for your model to be trained (or even more on older hardware).

# %%
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_loader)
    test_loop(dev_loader)
# Out:
# Epoch 1
# -------------------------------
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# loss: 1.035603  [    0/ 8040]
# loss: 0.698655  [ 1280/ 8040]
# loss: 0.497677  [ 2560/ 8040]
# loss: 0.357416  [ 3840/ 8040]
# loss: 0.254622  [ 5120/ 8040]
# loss: 0.197506  [ 6400/ 8040]
# loss: 0.150517  [ 7680/ 8040]
# Test avg loss: 0.216174
#
# Epoch 2
# -------------------------------
# loss: 0.144272  [    0/ 8040]
# loss: 0.126434  [ 1280/ 8040]
# loss: 0.114397  [ 2560/ 8040]
# loss: 0.104307  [ 3840/ 8040]
# loss: 0.100783  [ 5120/ 8040]
# loss: 0.098105  [ 6400/ 8040]
# loss: 0.093436  [ 7680/ 8040]
# Test avg loss: 0.251474
#
# Epoch 3
# -------------------------------
# loss: 0.092174  [    0/ 8040]
# loss: 0.089811  [ 1280/ 8040]
# loss: 0.087580  [ 2560/ 8040]
# loss: 0.084810  [ 3840/ 8040]
# loss: 0.082642  [ 5120/ 8040]
# loss: 0.078528  [ 6400/ 8040]
# loss: 0.076976  [ 7680/ 8040]
# Test avg loss: 0.153946
#
# Epoch 4
# -------------------------------
# loss: 0.075130  [    0/ 8040]
# loss: 0.075371  [ 1280/ 8040]
# loss: 0.071603  [ 2560/ 8040]
# loss: 0.071738  [ 3840/ 8040]
# loss: 0.067147  [ 5120/ 8040]
# loss: 0.067267  [ 6400/ 8040]
# loss: 0.064104  [ 7680/ 8040]
# Test avg loss: 0.087936
#
# Epoch 5
# -------------------------------
# loss: 0.063350  [    0/ 8040]
# loss: 0.062936  [ 1280/ 8040]
# loss: 0.061727  [ 2560/ 8040]
# loss: 0.058805  [ 3840/ 8040]
# loss: 0.059281  [ 5120/ 8040]
# loss: 0.056897  [ 6400/ 8040]
# loss: 0.056285  [ 7680/ 8040]
# Test avg loss: 0.063331

# %% [markdown]
# ## Evaluating the model
#
# Not that we trained the model, we can evaluate it. First, we'll check how the model does on an example from the development set. Note that the model will most likely not be fully trained after only five epochs.

# %%
sample = dev_generator[np.random.randint(len(dev_generator))]

fig = plt.figure(figsize=(15, 10))
axs = fig.subplots(3, 1, sharex=True, gridspec_kw={"hspace": 0, "height_ratios": [3, 1, 1]})
axs[0].plot(sample["X"].T)
axs[1].plot(sample["y"].T)

model.eval()  # close the model for evaluation

with torch.no_grad():
    x = torch.tensor(sample["X"]).to(model.device).unsqueeze(0)
    x_preproc = model.annotate_batch_pre(x, {})  # Remove mean and normalize amplitude
    pred = model(x_preproc)  # Add a fake batch dimension
    pred = pred[0].cpu().numpy()

axs[2].plot(pred.T)
# Out:
# [<matplotlib.lines.Line2D at 0x79b8237af050>,
#  <matplotlib.lines.Line2D at 0x79b8237e6050>,
#  <matplotlib.lines.Line2D at 0x79b8238fe490>]

# %% [markdown]
# As a second option, we'll directly apply our model to an obspy waveform stream using the `annotate` function. For this, we are downloading waveforms through FDSN and annotating them. Note that you could use the `classify` function in a similar fashion.
#
# As we trained the model on Swiss data, we use an example event from Switzerland. Note that we deliberately chose a rather easy example, as the model is not fully trained after the low number of epochs. The exact performance of the model will vary depending, because the model training and initialization involves random aspects.

# %%
client = Client("ETH")

t = UTCDateTime("2019-11-04T00:59:46.419800Z")
stream = client.get_waveforms(network="CH", station="EMING", location="*", channel="HH?", starttime=t-30, endtime=t+50)

annotations = model.annotate(stream)

fig = plt.figure(figsize=(15, 10))
axs = fig.subplots(2, 1, sharex=True, gridspec_kw={'hspace': 0})

offset = annotations[0].stats.starttime - stream[0].stats.starttime
for i in range(3):
    axs[0].plot(stream[i].times(), stream[i].data, label=stream[i].stats.channel)
    if annotations[i].stats.channel[-1] != "N":  # Do not plot noise curve
        axs[1].plot(annotations[i].times() + offset, annotations[i].data, label=annotations[i].stats.channel)

axs[0].legend()
axs[1].legend()
axs[0].set_xlim(10, 70)
axs[1].set_ylim(0, 1)
# Out:
# (0.0, 1.0)

# %% [markdown]
# ## Remarks
#
# As discussed in the data basics tutorial, loading a SeisBench dataset only means loading the metadata into memory. The waveforms are only loaded once they are requested to save memory. By default, waveforms are **not** cached in memory. For training, this means that the data needs to be read from the file in every epoch again. Depending on your hardware, this will take a lot of time. To solve this issue, you can set the `cache` option, when creating the dataset. Then, all you have to do is call `preload_waveforms` and the data will be loaded into memory and automatically cached. For most practical applications, this option is recommended.
#
# You might notice that for normalization we use the `annotate_batch_pre` function. This function implements all preprocessing on batch level, such as removing mean and normalizing the amplitude. The same function is used internally when calling `annotate` or `classify`. Using the same function in training ensures the consistent processing required for optimal performance.
